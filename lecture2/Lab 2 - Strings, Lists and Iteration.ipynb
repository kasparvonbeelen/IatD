# %% [markdown]
# -- Many of the materials are gently stolen from the following courses:
# - **["A Python Course for the Humanities"](https://github.com/fbkarsdorp/python-course)** a course designed by Folgert Karsdorp and Maarten van Gompel
# - and later modified by Mike Kestemont and Lars Wieneke for the course **["Programming for Linguistics and Literature"](https://github.com/mikekestemont/prog1617)**
# - **["Python for text analysis"](https://github.com/cltl/python-for-text-analysis)** designed by H.D. van der Vliet and taught at the Vrije Universiteit
# - **["How to Think Like a Computer Scientist"](http://www.greenteapress.com/thinkpython/thinkCSpy.pdf)** by Allen Downey, Jeffrey Elkner, Chris Meyers

# %% [markdown]
# # Lab Session 2: Strings, Lists and Iteration

# %% [markdown]
# ### --Exercise--
#
# Just as a quick reminder: Python has several in-built data types, integers (1,3,100), floats (1.0, 2.5) and strings ('iii'). Complete the exercise below.

# %%
# print a string here
# print a float here
# print an integer here

# %%
x = open('alice.txt').read()
print(len(x))

# %%
a_replaced = x.replace('a','ö')
print()

# %% [markdown]
# ## 1 Strings

# %% [markdown]
# Let's have a closer look at the ``'str'`` type (str stands for string)
#
# Both numbers and strings can be added together. What do you think the operation below will produce?

# %%
first_name = # Insert your first name here
last_name = # Insert you last name here
print(first_name+last_name)

# %% [markdown]
# This the last operation is called string **concatination**.

# %%
book = "The Lord of the Flies"
print(first_name + " likes " + book + "?")

# %% [markdown]
# ### --Exercise--

# %%
# declare three variables first_name, white space and last_name
# print them neatly using concatenation

# %%
# try other operators (such as *, +, /, -)on the first_name and last_name variables
# what works, what does not work? can you explain why?
# e.g "yourname"*2

# %% [markdown]
# You can do more than just applying operators to strings. We have a closer look at string manipulation later in the course, but at this stage, it is useful to be aware of Python's **`help()` function**.

# %%
# Get help!
help(str)

# %% [markdown]
# ## 1.2 Doing Things with Strings

# %% [markdown]
# ### 1.2.1 Creating and Reading Text

# %% [markdown]
# As we've seen you, can create string variables by typing text into your Notebook, put it between quotation marks and assign it to variable name using ``=``.

# %%
name = 'Kaspar'

# %% [markdown]
# Another option is to read a text from your **disk**. The syntax may look complicated but don't worry about it now. In the cell below we load some paragraph's from [Lewis Carrol's "Alice in Wonderland".](http://www.gutenberg.org/cache/epub/28885/pg28885.txt)

# %%
alice = open('./alice.txt').read()

# %%
print(alice)

# %% [markdown]
# ``open`` creates a connection between your Python Notebook and the file with the path './alice'. './' stands for current directory'. In this directory we open to the file with the name 'alice.txt'. Note, that opening a file isn't equal to reading it. Run the cell below to see what happens.

# %%
open_alice = open('./alice.txt')
print(open_alice)

# %% [markdown]
# It returns a file object but does not read its content. For this reason we have to call the ``read()`` method explicitly.

# %%
alice_read = open('./alice.txt').read()
print(alice_read)

# %% [markdown]
# ### --Exercise--
#
# - Open a text editor (not Word!), e.g. TextEdit on MacOS.
# - Copy-paste some paragraphs from Oscar Wilde's "The Picture of Dorian Gray"
# - Save it as 'gray.txt' **in the same folder as your Notebook**
# - Make sure you save it as **plain text** (Format > Make Plain Text) and use UTF-8 as encoding.
# - Open and read the file.
# - Print the content

# %%
# Add you code here

# %% [markdown]
# ### 1.2.2 Playing around with text in Python

# %% [markdown]
# In Python, everything is an object--for example "Hello, World!" is a string object. To make things easier for you, Python provides you with a lot of tools--called **functions or methods**--to manipulate **or** ask question about these objects.

# %% [markdown]
# ###  1.2.2.1 ``len()``

# %% [markdown]
# You can apply ``len()`` to any expression that evaluates to a string object. Put the string between the parentheses of ``len()`` (more formally, pass the string as an argument to the ``len()`` function.)
#
# For example:
#
# ``len(argument)``

# %% [markdown]
# ### --Exercise--
#
# Try to figure what the ``len`` function does, by adapting the above code cell.

# %%
len('Hello, World!!')

# %% [markdown]
# Ok, why is this useful? We can derive simple analytics from our data, for example count the number of characters in Alice and Wonderland.

# %%
alice_full = open('./fulltext/alice.txt').read()
print(len(alice_full))

# %% [markdown]
# We can do more, for example asking which book is longer.

# %% [markdown]
# ### --Exercise--
#
# - Read the file 'gray.txt' in the folder 'fulltext'.
# - Print how many characters this file contains. Is it shorter or longer? What are you counting here?
# - Save the length of both books to two variables (length_alice and length_gray)

# %%
# Add code here

# %% [markdown]
# ### --Exercise--
#
#  As you noticed `len()` evaluates to a number, which counts the characters in a string. What is the length of Alice and Dorian Gray combined?

# %%
# Add code here

# %% [markdown]
# We can ask other types of question such as: does string X appear in string Y? For this we use the ``in`` operator.

# %%
'mother' in 'to be smothered'

# %%
'mothers' in 'to be smothered'

# %% [markdown]
# Both expression evaluate to boolean values: ``True`` or ``False``.

# %% [markdown]
# We can formulate more precise conditions, for examples asking Python is a string starts or ends with a specific value.

# %%
"foodie".startswith("foo")

# %%
"foodie".endswith("foo")

# %% [markdown]
# ### --Exercise--
#
# Write an expression that checks whether a string is a valid Twitter Hashtag.

# %%
# add code here

# %% [markdown]
# ### --Exercise--
#
# Write an expression that checks whether documents in the folder 'fulltext' are '.txt' files

# %%
# add code here

# %% [markdown]
# But Python comes with more directly useful string methods such as searching and counting.

# %% [markdown]
# While the `in` operator tells you that substring occurs in some other string (or not), is does not show you where and how often. To discover where the substring is located we can use the `.find()` method. `.find()` is applied to a string object and requires one parameter: a substring, which will be searched for within the string whose `.find()` method was called. More formally:
#
#
# ``string.find(substring)``
#
#
# If the substring is found, the entire expression will evaluate to the index at which the substring is found. If the substring is not found, the expression evaluates to `-1`.

# %%
print("kaspar".find("k"))
print("kaspar".find("a"))
print("kaspar".find("ar"))
print("kaspar".find("@"))

# %% [markdown]
# Please notice the following:
# - In Python we start counting at zero. The index of the first character 'k' is 0. This may be confusing at first, but you'll get used to it.
# - Find only returns the position of the first occurence of the your query.

# %% [markdown]
# ### --Exercise--
#
# - Find the position of the hashtag in Trump's tweet.
# - Where is the hashtag located?
# - Are there any mentions (@) in these tweets?

# %%
tweet = """Just landed in West Virginia. Big crowd, looking forward to seeing everyone soon! #MAGA"""

# %%
tweet_2 = """Will be going to the Great State of West Virginia on Tuesday Night to campaign & do a Rally Speech
for a hard working and spectacular person, A.G. Patrick Morrisey, who is running for the U.S. Senate. 
Patrick has great Energy & Stamina-I need his VOTE to MAGA. Total Endorsement!"""

# %%
# add you code here

# %% [markdown]
# We can also count how often certain patterns appear in a text. The syntax should look familiar by now:
#
# ``string.find(substring)``

# %%
tweet_2.count('is')

# %% [markdown]
# Instead of just tweets we can apply these methods to whole books.

# %%
alice = open('./fulltext/alice.txt').read()
alice.count('Alice') # How often is Alice mentioned?

# %% [markdown]
# ### --Exercises--
#
# - How often does the pronoun "she" appear? in Alice
# - How often is Dorian Gray mentioned in Wilde's book? How often is the word "he" mentioned?

# %%
# Add your code here

# %% [markdown]
# ### --Exercise--
#
# - Test if count is case-sensitive

# %%
# Add your code here

# %% [markdown]
# ## String Transformations

# %% [markdown]
# As you've noticed, `count` is case-sensitive: you get different results, for example, when searching for "she" or "She". In case we want to ignore capitalization (something we often do when processing text) Python allows us to easily **lowercase** a string.
#
# 'str.lower()' evaluates to a copy `str` with all characters transformed to lower case.

# %%
"DON'T YELL!!!".lower()

# %% [markdown]
# ``.upper()`` performs the opposite transformation, returning a copy of the string all in capitals

# %%
'yell!'.upper()

# %% [markdown]
# ### --Exercise--
#
# - Lowercase Alice in Wonderland and assign to a variable `alice_lower`.
# - Count the occurance of the string 'rabbit' in both the original and the lowercased version.

# %%
# Add your code here

# %% [markdown]
# `.replace()` method takes two parameters: a string to find, and a string to substitute that string with. [You can use this to make sad stories.](http://rwet.decontextualize.com/schedule/)

# %%
"I got rhythm, I got music, I got my man, who could ask for anything more".replace("I got", "I used to have")

# %% [markdown]
# We can also apply ``.replace()`` to counter stereotypes.

# %%
'He works at the office, she takes cares of the kids.'.replace('she','he').replace('He','She')

# %% [markdown]
# ### --Exercise--
#
# - Make a simple script that the replaces 'her' with 'his' in the sentence.
# > 'I borrowed his book and her pen'
# - transform the sentence to uppercase
# - assigned the result to a new variable named ``upper_gender``

# %%
# Add your code here
'fulltext/alice.txt'.endswith('.txt')
# Out:
# True

# %% [markdown]
# ### --Exercise--
#
# - Can you explain why, if we want to switch genders (he with she and vice versa), the following code does not yield the expected result?
# - Can you find a solution?

# %%
print('he works at an office, she stays at home.'.replace('she','he').replace('he','she'))
print('he works at an office, she stays at home.'.replace('he','she').replace('she','he'))

# %%
# Add your code here

# %% [markdown]
# # 2 Indexing and slicing

# %% [markdown]
# Often we want to select a substring from a string value (or more generally a subset of elements from a collection). Python notation for **indexing** and **slicing** may be confusing at first, but very useful once you are familiar with it.

# %%
song = "Naturkatastrophenkonzert"
print(song)

# %% [markdown]
# As we know by now, such a piece of text ("Naturkatastrophenkonzert") is called a ``string`` in Python (cf. a **string of characters**). Strings in Python must always be enclosed with 'quotes' (either **single** or **double** quotes). *Without those quotes, Python will think it's dealing with the name of some variable that has been defined earlier because variable names never take quotes.* The following distinction is confusing, but extremely important (for this reason I repeat it here): variable names (without quotes) and string values (with quotes) look similar, but they serve a completely different purpose. Compare:

# %%
name = "Doris"
Doris = "name"
D = "D"
print(name)
print (Doris)
print(D)

# %% [markdown]
# Now that you know the difference between variables and string values, we can inspect these strings further. Strings are called strings because they consist of a **series** (or ``'string'``) of **individual** characters. We can access these characters in Python with the help of **``'indexing'``** because each character in a string has a unique **``'index'``** (i.e. an integer that points to the position of the character). To print the first letter of the variable `song`, you can type:

# %%
song_startswith = song[0]
print(song)
print(song_startswith)

# %% [markdown]
#  Or try:

# %%
#print("Starts with: ",song_startwith)

# %% [markdown]
# ### How does indexing work exactly?
#
# ![Indexes of the string Monty Python starting with 0](https://i.stack.imgur.com/vIKaD.png)
# Take a look at the string "Monty Python". We use the index **`0`** to access the **first** character in the string. This might seem odd, but all indexes in Python start at **zero**. Whenever you count in Python, you start at `0` instead of `1`. Note that the **space character** gets an index too, namely 5. This is something you will have to get used to!
#
# How to access the last letter of "Naturkatastrophenkonzert"? Python has a `len()` function, which tells you how many elements the sequence contains

# %%
# get the length of the song variable 
len(song)

# %% [markdown]
# Because you know the length of the song name you can ask for the last letter of "Naturkatastrophenkonzert":

# %%
last_letter = song[len(song)]
print(last_letter)

# %% [markdown]
# Ouch, this raises an `IndexError`--again because we start counting at zero, not at one!

# %% [markdown]
# The example below offers a solution. Do you understand the following statement? Adapt it so it prints the last character of the `song` variable.

# %%
print(name[len(name)-1])

# %% [markdown]
# It is rather inconvenient having to know how long our strings are if we want to find out what its last letter is. Python provides a simple way of accessing a string 'from the rear':

# %%
# Exercise print the last letter of your name using a negative index
last_letter = song[-1]
print(last_letter)

# %% [markdown]
# Now can you write some code that defines a variable `but_last_letter` and assigns to this variable the *one but last* letter of your name?

# %%
name = # enter your name as a string

# %%
but_last_letter = name[-2]
print(but_last_letter)

# %% [markdown]
# You're starting to become a real expert in indexing strings. Now, what if we would like to find out what the first two or three letters of our name are? In Python we can use so-called **'slice-indexes' or 'slices'** for short. To find the first two letters of our name we type in:

# %%
first_two_letters = name[0:2]
print(first_two_letters)

# %% [markdown]
# The `0` index is optional, so we could just as well type in `name[:2]`. This says: take all characters of the  `name` variable until you reach index 2 (i.e. up to the third letter, but not including the third letter). We can also start at index 2 and leave the end index unspecified:

# %%
without_first_two_letters = name[2:]
print(without_first_two_letters)

# %% [markdown]
# Because we did not specify the end index, Python continues until it reaches the end of our string. If we would like to find out what the last two letters of our name are, we can type in:

# %%
last_two_letters = name[-2:]
print(last_two_letters)

# %% [markdown]
# ### General Slice Syntax
#
# The more general form of the Python slicing syntax has the shape
#
#    `object[start:stop:step]`
#
# Complete the three exercises below, to check if you properly understand this syntax.

# %%
# Exercise: print your name, but only the characters with an even index

# %%
# Exercise: what happens when you use a negative step without defining the start and end of the slice?

# %%
# Exercise: what happens if we apply [::] (or [:::]) to a variable?

# %% [markdown]
# # 3. Iteration and Conditions

# %% [markdown]
# # Demo Cell

# %%
#-repetition: repeat operations using a for loop
#for char in 'Kaspar':
#print(char*2)
#print(char*3)
#print('r')

#-Control with conditional expression
#-Boolean expression act as gates to the parts of the code
#-Boolean expression evaluate to True or False
#grade = 5
#print(grade > 10)
#print(grade < 10)

#print('a' in 'Kaspar')
#print('o' in 'Kaspar')

#-Control with if
grade = 2
if grade > 5:
    print(grade)

#-Control with if-else: different output depending on location in the for loop
#grades = [9,3,5,7,10,6,2,4,8]
#for grade in grades:
#    if grade > 5:
#        print('You pass!')
#    else:
#        print('Nope.')

#-Indentation!

# %% [markdown]
# As should be clear by now, strings are a sequence of characters. With indexing and slicing, you can retrieve elements at specific positions and substrings located between two indices.
#
# But there is more: we can also iterate over the string, and do something with each character. For example, if we want to print a cat after each character in the word 'superCATifragilisticexpialidocious', we can use the following code:

# %%
for char in 'superCATifragilisticexpialidocious':
    print(char,"🐱")
# Out:
# s 🐱
# u 🐱
# p 🐱
# e 🐱
# r 🐱
# C 🐱
# A 🐱
# T 🐱
# i 🐱
# f 🐱
# r 🐱
# a 🐱
# g 🐱
# i 🐱
# l 🐱
# i 🐱
# s 🐱
# t 🐱
# i 🐱
# c 🐱
# e 🐱
# x 🐱
# p 🐱
# i 🐱
# a 🐱
# l 🐱
# i 🐱
# d 🐱
# o 🐱
# c 🐱
# i 🐱
# o 🐱
# u 🐱
# s 🐱

# %% [markdown]
# The `for` statement indicates iteration. It tells the program to do the same thing “for” each element of the string. Each item in the string is given the label `char`: i.e. initially num is 's', then `char` is 'u'. At each step we perform the same operation on `char`. You can think of a `for` loop as rummaging through a pile of books, take out one book, do something with it, put it somewhere else, take the next one, until the bottom of the pile.

# %% [markdown]
# `for` loops follow a simple structure:
#
# for `x` in `iterable`:
#
#     perform an operation on x

# %% [markdown]
# `for` and `in` are the fixed parts of the iteration template. The name of the variable that will take the value of each items in the iterable (i.e. `char` or `x` in the above examples) is free, as long as it is used consistently.

# %%
for LALALALALALALALA in 'Kaspar':
    print(LALALALALALALALA)

# %% [markdown]
# You are **free to choose the name** of this variable, but it has to be consistent in the **indented** block below. The previous example works, but is not very convenient.

# %%
for char in 'Kaspar':
    print(character)

# %% [markdown]
# The preceding code yields a `NameError`, because 'character' is only defined if it **appears** between `for` and `in`.

# %% [markdown]
# `x` is the variable that will hold (i.e. take the value) of each element in the `iterable` object. As said earlier, it allows you to do something with each individual character in the string.

# %% [markdown]
# We can make a program that will print only vowels and censor the consonants, using the membership operator and `if ... else` condition (something we study in more detail later)

# %%
word = 'superCATifragilisticexpialidocious'
for char in word:
    if char in 'aeuio':
        print(char)
    else:
        print('-')

# %% [markdown]
# We can make it look a bit cooler, by tweaking the print function (don't worry about what is happening here)

# %%
word = 'supercatifragilisticexpialidocious'
for char in word:
    if char in 'aeuio':
        print(char,end='',flush=True)
    else:
        print('🐱',end='',flush=True)
# Out:
# s🐱p🐱rc🐱t🐱fr🐱g🐱l🐱st🐱c🐱xp🐱🐱l🐱d🐱c🐱🐱🐱s

# %% [markdown]
# ## --Exercise--
#
# Write a program that replaces vowels with cat emoticons and prints only the consonants. Print it nicely on one line.
#
# *HINT*: Change the previous code, but use `not` before `in`, i.e. `not in`

# %%
word = 'supercatifragilisticexpialidocious'
for char in word:
    if char not in 'aeuio':
        print(char,end='',flush=True)
    else:
        print('🐱',end='',flush=True)
# Out:
# s🐱p🐱rc🐱t🐱fr🐱g🐱l🐱st🐱c🐱xp🐱🐱l🐱d🐱c🐱🐱🐱s

# %% [markdown]
# ## --Exercise--
#
# Make a program the opens Alice (the short version). and makes it look Swedish by
# - replacing e with ur
# - replacing aeo with ö.
#
# **HINT**: Use two following sequence of conditional statements.
#
#  ``
# if ...:
# elif ...:
# else:
#       ...``

# %%
text = open('alice.txt').read()
for i in text:
    if i in #add code here:
        print(,end='',flush=True)
    elif # add code here:
         # add code here
    else:
        # add code here

# %% [markdown]
# ### --Exercise--
#
# Can you obtain the same result with .replace()?

# %%
'o' in 'aeio'
# Out:
# True

# %% [markdown]
# # 4. Lists

# %% [markdown]
# # Demo Cell

# %%
#-Accessing information using index notation
hello = "Hello, world!"
#print(hello[0])
#print(hello[-1])

# --------- #

#-Convert a string (sequence of characters) to a list(sequence of words)
#-use .split() method
hello.split()
#print(hello.split())
#print(type(hello.split()))
hello_splitted = hello.split()
#print(type(hello_splitted))
print(hello_splitted[0])
# --------- #

#-Split on whitespace or any other character
print(hello.split('o'))
#print(hello.split('o,'))

# --------- #

#-Parsing information (e.g. CSV)
line = '5,5,7,2,5,0'
numbers = line.split(',')
print(numbers)

# --------- #
#-Asking questions to list
#-Boolean questions
#print('2' in numbers)

#-Count items
print(numbers.count('5'))

# --------- #
#-Demo song finder
# Out:
# Hello,
# ['Hell', ', w', 'rld!']
# ['5', '5', '7', '2', '5', '0']
# 3

# %% [markdown]
# Consider the first sentence (represented as a string) from Franz Kafka's book 'The Trial'. Imagine for a moment that we have assigned the whole book to the `trial` variable.

# %%
trial = "Someone must have slandered Josef K., for one morning, without having done anything truly wrong, he was arrested. "

# %% [markdown]
# How can we select specific words from this book? It may seem more natural for humans to describe it as a series of words, rather than as a series of characters. Say, we want to access the first word in our sentence. If we enter:

# %%
first_word = trial[0]
print(first_word)

# %% [markdown]
# **`split()` converts this string to a list of words.**
#
# Python only prints the first character of our sentence. (Think about this if you do not understand why.) We can, however, transform our sentence into a list of words (represented by strings) using the split() function as follows:

# %%
words = trial.split()
print(words)

# %% [markdown]
# The variable `trial` now holds the first line of Kafka's Trial as a **list**. Each element in this list is now (approximately) a word. Run the code below to see the difference.

# %%
first_word = words[0]
print(first_word)

# %% [markdown]
# We apply the `split()` function to the variable `trial` and we assign the result of the function (we call this the 'return value' of the function) to the new variable `words`.

# %% [markdown]
# ### --Exercise--
# Split the first line of Genesis and assign the list to the variable `bible`
# "In the beginning God created the heaven and the earth."

# %%
# add your code here
line = 'In the beginning God created the heaven and the earth'
line_splitted = 'In the beginning God created the heaven and the earth'.split()
print(line_splitted)
# Out:
# ['In', 'the', 'beginning', 'God', 'created', 'the', 'heaven', 'and', 'the', 'earth']

# %% [markdown]
# **`split()` takes other delimiters as arguments.**
#
# By default, the split() function in Python will split strings on the **spaces** between words (and it will return a list of words). However, we can pass an **argument** to `split()` that specifies explicitly the string we would like to split on.
#
# This is often useful for **parsing** information from a CSV file (or other structured data). For example, the line below has the structure of the [Google Ngram](https://books.google.com/ngrams). The Ngram Viewer allows the researcher to explore long-term cultural [trends](https://books.google.com/ngrams/graph?content=king%2C+queen&case_insensitive=on&year_start=1800&year_end=2000&corpus=15&smoothing=3&share=&direct_url=t4%3B%2Cking%3B%2Cc0%3B%2Cs0%3B%3Bking%3B%2Cc0%3B%3BKing%3B%2Cc0%3B%3BKING%3B%2Cc0%3B.t4%3B%2Cqueen%3B%2Cc0%3B%2Cs0%3B%3BQueen%3B%2Cc0%3B%3Bqueen%3B%2Cc0%3B%3BQUEEN%3B%2Cc0). The source data of this corpus comprises the yearly word and document frequencies for ~ 5 million books printed between 1500 and 2008. The lines are separated by hard returns ("\n"). Each line holds four elements: word, year, word frequency, document frequency.
#
# Using the split function, we can easily **parse** this file, i.e. recognize and read its content. First, we split the string by their "\n" and then each line by their "\t" which stands for a "tab".
#
# In the code block below, we will split a string on tabs, instead of spaces. Do you get the syntax?

# %% [markdown]
# ### --Exercise--
#
# Parse the CSV data stored in `google_ngram`. Complete the code below.

# %%
# note the `\n` symbol
google_ngram = "queen\t1900\t20394\t3435\nqueen\t1901\t23340\t2935\nqueen\t1902\t23120\t3035"
print(google_ngram)
google_ngram = google_ngram.split() # complete code here
print(google_ngram)
first_line = google_ngram[0]
print(first_line.split()) # complete code here

# %% [markdown]
# .split() acts on a string and evaluates to a list. But you can also manually create a list. We can  create lists by enclosing the individual items within square brackets, separated by a comma.

# %%
my_grades = [8,9,6,7]
print(my_grades)
my_garbage = ['Potatoe',[1,2,3],9.03434,'frogs']
print(my_garbage)

# %% [markdown]
# ### General rules:
# * Lists are surrounded by square brackets and the elements in the list are separated by commas
# * A list element can be **any Python object** - even another list (e.g. * List can be a collection of numbers, strings, floats (or a combination thereof))
# * A list can store values with different types
# * A list can be empty

# %% [markdown]
# ### --Exercise--
#
# Create a list that contains three objects.

# %%
# add your code here

# %% [markdown]
# Similar to strings, we can retrieve elements by their index or extract slices.

# %%
grades = '9,2,3,4,5,6,6,9'
grades_splitted = grades.split(',')
print(grades_splitted)

# %%
print(grades_splitted[0])
print(grades_splitted[-1])
print(grades_splitted[3:7])

# %% [markdown]
# ## Asking questions to lists
#
# You can use lists in **membership boolean expressions** (See Notebook 2.2). The `in` operator checks whether the item 'God' appears in the variable `bible`.

# %%
bible = ['In', 'the', 'beginning', 'God', 'created', 'the', 'heaven', 'and', 'the', 'earth.']
print('God' in bible)

# %% [markdown]
# This is often useful for checking if a text contains a specific word. For sure, the line below returns the same result.

# %%
'God' in 'In the beginning God created the heaven and the earth.'

# %% [markdown]
# But it matches the string **not** the "word"!

# %%
print('God' in 'My Godess created the heaven and the earth.')
print('God' in ['My', 'Godess', 'created', 'the', 'heaven', 'and', 'the', 'earth.'])

# %% [markdown]
# Explain to yourself why the first expression evaluates to `True` while the latter returns `False`.

# %%
# add your answer here

# %% [markdown]
# ### Counting

# %%
['a','b','a','c','a','aa'].count('a')

# %% [markdown]
# ### --Exercise--
#
# - Load Alice and Dorian Gray into your Notebook.
# - Split the string into "words".
# - Count how often the article (i.e. everything between spaces) "a" and "the" appear in Alice. Do the same for Dorian Gray.
# - Do not forget to lowercase!
# - Divide the frequency of the "a" and "the" by the total number of words.
# - What does this number mean?

# %%
alice = open('fulltext/alice.txt','r').read().split()
#gray = open('fulltext/gray.txt')
len(alice)
# Out:
# 27291

# %% [markdown]
# ### --Exercise--
#
# Try to understand the code below; try to understand what happens at each line and recreate the code by yourself (i.e. without looking at the example). Congratulations you build your first search script!

# %%
import requests
url = 'https://labrosa.ee.columbia.edu/millionsong/sites/default/files/AdditionalFiles/tracks_per_year.txt'
#small data set for those with a slower laptop/computer
#url = ‘https://raw.githubusercontent.com/kasparvonbeelen/Coding-the-Humanities/master/lecture2/subsample.txt’

# %%
data = requests.get(url).text.strip() # don't worry about this line
song_titles = data.split('\n')
search = 'love'
for row in song_titles:
    row_splitted = row.lower().split()
    if search in row_splitted:
        print(row)
# Out:
# 1922<SEP>TRRAHXQ128F42511FF<SEP>Barrington Levy<SEP>Looking My Love
# 1925<SEP>TRQYSYF128F935F350<SEP>Bessie Smith<SEP>Careless Love Blues
# 1928<SEP>TRMUXQE128F426D9E7<SEP>Lonnie Johnson<SEP>Careless Love
# 1930<SEP>TROQDDT128F42271E6<SEP>Casa Loma Orchestra<SEP>Anytime's the Time to Fall in Love
# 1937<SEP>TRWQDOL12903CB11EB<SEP>Billie Holiday<SEP>Without Your Love
# 1937<SEP>TRAAQJE12903C97241<SEP>Billie Holiday<SEP>I've Got My Love To Keep Me Warm
# 1937<SEP>TRDFACX12903CD251F<SEP>Billie Holiday<SEP>Without Your Love
# 1942<SEP>TRPUJXT12903D0C4FD<SEP>Jimmie Davis<SEP>I Dreamed of an Old Love Affair
# 1947<SEP>TRDPPGU128F92FE2EB<SEP>Billie Holiday<SEP>There Is No Greater Love
# 1947<SEP>TRKMQGP128F9327288<SEP>Billie Holiday<SEP>There Is No Greater Love
# 1948<SEP>TRLYGGS128F930DCEE<SEP>Hank Williams<SEP>My Sweet Love Ain't Around
# 1948<SEP>TRCNHXW12903CFD2FB<SEP>Jimmy Wakely<SEP>I Love You So Much it Hurts
# 1948<SEP>TRBMNAR128F930DEFB<SEP>Jimmy Wakely<SEP>I Love You So Much It Hurts
# 1948<SEP>TRNNMCI128F92FA2B5<SEP>Jimmy Wakely<SEP>I Love You So Much It Hurts
# 1948<SEP>TRSZZPW12903CDE03E<SEP>Jimmy Wakely<SEP>I Love You So Much It Hurts
# 1949<SEP>TRDWCCX12903CB5C7A<SEP>Cole Porter<SEP>So In Love
# 1949<SEP>TRYJJVY12903CB5CA3<SEP>Cole Porter<SEP>So In Love
# 1949<SEP>TRWWXAK12903CBD352<SEP>Leon Payne<SEP>I Love You Because
# 1949<SEP>TRHLSCD128F4251C25<SEP>Leon Payne<SEP>I Love You Because
# 1949<SEP>TRQZWTN12903CA9198<SEP>Leon Payne<SEP>I Love You Because
# 1949<SEP>TRZYBYO128F9359720<SEP>Leon Payne<SEP>I Love You Because
# 1949<SEP>TRILQIZ12903CB8338<SEP>Leon Payne<SEP>I Love You Because
# 1949<SEP>TRYPWIY128F932AE73<SEP>Leon Payne<SEP>I Love You Because
# 1949<SEP>TRFDRLZ12903C956E6<SEP>T-Bone Walker<SEP>First Love Blues
# 1950<SEP>TRMBVKJ12903CB65B7<SEP>Percy Mayfield<SEP>Please Send Me Someone to Love
# 1950<SEP>TRZHVKZ128F427EE5E<SEP>Percy Mayfield<SEP>Please Send Me Someone To Love
# 1950<SEP>TRIIWSR128F428002A<SEP>Percy Mayfield<SEP>Please Send Me Someone To Love
# 1950<SEP>TRAVEOQ128F931C8F4<SEP>Percy Mayfield<SEP>Please Send Me Someone To Love
# 1950<SEP>TRPTYKQ128F42A73B8<SEP>Percy Mayfield<SEP>Please Send Me Someone To Love
# 1950<SEP>TRLDQTP128F9311E19<SEP>Percy Mayfield<SEP>Please Send Me Someone To Love
# 1950<SEP>TRJAXHK128F932059C<SEP>Percy Mayfield<SEP>Please Send Me Someone To Love
# 1950<SEP>TRVUKBK128F4278147<SEP>Percy Mayfield<SEP>Please Send Me Someone To Love
# 1951<SEP>TRUIMZU128E078985E<SEP>Hank Williams<SEP>I Can't Help It (If I'm Still In Love With You)
# 1952<SEP>TRJISBU128F429ADCA<SEP>Louis Armstrong<SEP>I Laughed At Love
# 1953<SEP>TRBMSVQ128F148B054<SEP>Jimmy Rogers<SEP>Act Like You Love Me
# 1953<SEP>TROULWQ128F932BE4D<SEP>Mabel Mercer<SEP>You Are Not My First Love
# 1954<SEP>TRLZTBM128F935A24C<SEP>Clyde McPhatter and the Drifters<SEP>Honey Love
# 1954<SEP>TRPIQFL128F92D40A1<SEP>Earl King<SEP>A Mother's Love
# 1954<SEP>TRYCBXS128EF34DCF7<SEP>Johnny Ace / The Johnny Otis Band<SEP>Saving My Love For You
# 1954<SEP>TRJYUNL128F931D948<SEP>Patti Page<SEP>All My Love
# 1955<SEP>TRXAIQF128F9341837<SEP>Chet Baker<SEP>You Don't Know What Love Is
# 1955<SEP>TRMQUAB128F428B4EC<SEP>Doris Day<SEP>Secret Love
# 1955<SEP>TRAPRJA12903CAFA4B<SEP>Doris Day<SEP>Secret Love
# 1955<SEP>TRLSMKG12903D02129<SEP>Doris Day<SEP>Secret Love
# 1955<SEP>TRVCTMY12903CB5377<SEP>Doris Day<SEP>Secret Love
# 1955<SEP>TRMCVJL12903CEB202<SEP>Johnny Ace<SEP>Pledging My Love
# 1955<SEP>TRHXFXO128F931D8B4<SEP>Johnny Ace<SEP>Pledging My Love
# 1955<SEP>TRCKNQD12903D0A2BC<SEP>Johnny Ace<SEP>Pledging My Love
# 1955<SEP>TRECTQY128F42A7775<SEP>Johnny Ace<SEP>Pledging My Love
# 1955<SEP>TRNVGPH128EF34DCFB<SEP>Johnny Ace / The Johnny Otis Band<SEP>Pledging My Love
# 1955<SEP>TRRNWXR12903CC9CE7<SEP>Julie London<SEP>I Love You
# 1955<SEP>TRFJVAK128F422D682<SEP>Julie London<SEP>I Love You
# 1955<SEP>TRVQOJB128F4232589<SEP>Julie London<SEP>I'm In The Mood For Love
# 1955<SEP>TROUUFX12903CC9CB2<SEP>Julie London<SEP>I'm In the Mood for Love
# 1955<SEP>TRHCAAE12903D043F1<SEP>Sammy Davis Jr.<SEP>Easy To Love
# 1955<SEP>TRJNCWU12903CC5D61<SEP>Sammy Davis Jr.<SEP>Easy to Love
# 1956<SEP>TRCUHFN128E078E737<SEP>B.B. King<SEP>Please Love Me
# 1956<SEP>TRBFNLX128F4249752<SEP>B.B. King<SEP>Please Love Me
# 1956<SEP>TREALXP12903CB0441<SEP>B.B. King<SEP>You Know I Love You
# 1956<SEP>TRAXPEN128F933F4DC<SEP>B.B.King<SEP>Please Love Me
# 1956<SEP>TRWBBZC128F92F1B7F<SEP>Bing Crosby & Grace Kelly<SEP>True Love
# 1956<SEP>TRZIQZH128F423E546<SEP>Bing Crosby & Grace Kelly<SEP>True Love
# 1956<SEP>TRUCFRE128F92F2266<SEP>Bing Crosby & Grace Kelly<SEP>True Love
# 1956<SEP>TRLLUHU128F930DA3B<SEP>Bing Crosby & Grace Kelly<SEP>True Love
# 1956<SEP>TRVGAOT128F92D34A2<SEP>Bing Crosby & Grace Kelly<SEP>True Love
# 1956<SEP>TRGMBDR12903CEA3D1<SEP>Bing Crosby And Grace Kelly<SEP>True Love
# 1956<SEP>TRYZZUW128F932D54B<SEP>Bing Crosby And Grace Kelly<SEP>True Love
# 1956<SEP>TRTWBZR128F932AA3A<SEP>Bing Crosby_ Grace Kelly<SEP>True Love
# 1956<SEP>TRTYZHL12903CC8D4E<SEP>Bing Crosby_ Grace Kelly<SEP>True Love
# 1956<SEP>TRDJYUF128F92EFEE8<SEP>Bing Crosby_ Grace Kelly<SEP>True Love
# 1956<SEP>TRUWXSZ128F932E17F<SEP>Bing Crosby|Grace Kelly<SEP>True Love
# 1956<SEP>TRCRHGZ128F9339872<SEP>Chet Baker<SEP>I fall in love too easily
# 1956<SEP>TRJASMF128F428EA7E<SEP>Eddy Arnold<SEP>That's How Much I Love You
# 1956<SEP>TRYWUSU12903CBD1E2<SEP>Eddy Arnold<SEP>That's How Much I Love You
# 1956<SEP>TRSEKGC12903CAB349<SEP>Fats Domino<SEP>Careless Love
# 1956<SEP>TRRZFYG128F934DEEF<SEP>Frankie Lymon And The Teenagers<SEP>Why Do Fools Fall in Love
# 1956<SEP>TRUVBBY12903CEB5C2<SEP>Frankie Lymon And The Teenagers<SEP>The ABC's Of Love
# 1956<SEP>TRSAYAZ128F93492C1<SEP>Frankie Lymon And The Teenagers<SEP>Why Do Fools Fall In Love
# 1956<SEP>TRYGPTF12903CEB599<SEP>Frankie Lymon And The Teenagers<SEP>Why Do Fools Fall In Love
# 1956<SEP>TRYKCSL128F934D7FC<SEP>Frankie Lymon And The Teenagers<SEP>Why Do Fools Fall in Love
# 1956<SEP>TRCTNHQ128F92FA33F<SEP>Little Willie John<SEP>Need Your Love So Bad
# 1956<SEP>TRULMOS128F9300D4F<SEP>Lymon_ Frankie & The Teenagers<SEP>The ABC's Of Love
# 1956<SEP>TRCDRGT12903CE64BF<SEP>Otis Rush<SEP>My Love Will Never Die
# 1956<SEP>TRICHFK12903CE64A8<SEP>Otis Rush<SEP>Violent Love
# 1956<SEP>TRZLTJF12903D026DF<SEP>Sonny Rollins<SEP>You Don't Know What Love Is
# 1956<SEP>TRRPDNW128F9307B2F<SEP>The Teenagers<SEP>Why Do Fools Fall In Love
# 1956<SEP>TRIPHRB128F429B5D0<SEP>The Teenagers feat. Frankie Lymon<SEP>Why Do Fools Fall In Love
# 1957<SEP>TRWNGFK128F147B858<SEP>Bo Diddley<SEP>Who Do You Love
# 1957<SEP>TRHBQPJ12903CC58E6<SEP>Bo Diddley<SEP>Who Do You Love
# 1957<SEP>TRFJTWY12903CB4D16<SEP>Buddy Holly<SEP>Words of Love
# 1957<SEP>TRIITYY12903CCFF2D<SEP>Charlie Parker<SEP>I'M In The Mood For Love
# 1957<SEP>TRNBIPL128F422839C<SEP>Fats Domino<SEP>It's You I Love
# 1957<SEP>TRLAZLZ128F146AC3B<SEP>Fats Domino<SEP>It's You I Love
# 1957<SEP>TRBPLQK12903C9ECE5<SEP>Jackie Gleason<SEP>Our Love
# 1957<SEP>TRYVBKA12903C9ECD5<SEP>Jackie Gleason<SEP>I Love You Much Too Much
# 1957<SEP>TRVHHXX128F92EB41D<SEP>Johnny Mathis<SEP>Will I Find My Love Today
# 1957<SEP>TRXCMYZ12903CAB10C<SEP>Julie London<SEP>Make Love To Me
# 1957<SEP>TRDHHVQ128F92E6FDE<SEP>Kenny Dorham<SEP>Falling In Love With Love
# 1957<SEP>TRBHEQU128F932BDFE<SEP>LaVern Baker<SEP>I Can't Love You Enough
# 1957<SEP>TRNWJWQ128F92D9D97<SEP>LaVern Baker<SEP>I Can't Love You Enough
# 1957<SEP>TRGRZHA128F14ABAAF<SEP>Magic Sam<SEP>All Your Love
# 1957<SEP>TRHWVNW128F425160F<SEP>Magic Sam<SEP>All Your Love
# 1957<SEP>TRAARCW12903CEB779<SEP>Nat King Cole<SEP>When I Fall In Love
# 1957<SEP>TRQKUGZ128F92FB11C<SEP>Patsy Cline<SEP>Hungry for Love
# 1957<SEP>TRGYULN12903CA759C<SEP>Paul Anka<SEP>Don't Gamble With Love
# 1957<SEP>TRSTQKA128F92FA2CC<SEP>Paul Anka<SEP>Tell Me That You Love Me
# 1957<SEP>TRMDTEQ128F930853D<SEP>Red Garland<SEP>Please Send Me Someone to Love
# 1957<SEP>TRIVNFV128F931577F<SEP>Red Garland<SEP>Please Send Me Someone To Love
# 1957<SEP>TRAREPB128F93509A7<SEP>Red Garland<SEP>I Can't Give You Anything But Love
# 1957<SEP>TRUJQKA128F9350989<SEP>Red Garland<SEP>Please Send Me Someone To Love
# 1957<SEP>TREXUTU128F9309D2C<SEP>Red Garland<SEP>Please Send Me Someone to Love
# 1957<SEP>TRJKBIG128F9315782<SEP>Red Garland<SEP>Almost Like Being in Love
# 1957<SEP>TRDHMPO128F9315785<SEP>Red Garland<SEP>I Can't Give You Anything But Love
# 1957<SEP>TRGOWNC128F4272AD7<SEP>Slim Harpo<SEP>I Got Love If You Want It
# 1957<SEP>TRHANDJ128F148AF0E<SEP>Slim Harpo<SEP>I Got Love If You Want It
# 1957<SEP>TRBUCNA128F9300AC4<SEP>Slim Harpo<SEP>I Got Love If You Want It
# 1957<SEP>TRZGWVA128F92E6FDC<SEP>Sonny Rollins<SEP>There Is No Greater Love
# 1957<SEP>TRCQNHL128F4283B83<SEP>The 5 Royales<SEP>Dedicated To The One I Love
# 1957<SEP>TRPANDE12903CEDC0E<SEP>The Everly Brothers<SEP>Bye Bye Love
# 1957<SEP>TRYIVBL128F931EC14<SEP>The Everly Brothers<SEP>Bye Bye Love
# 1957<SEP>TRMNRLB128F93309F4<SEP>The Monotones<SEP>Book Of Love
# 1957<SEP>TRFJAEH128F9301090<SEP>The Monotones<SEP>Book Of Love
# 1957<SEP>TRPXMVN128F930E195<SEP>The Monotones<SEP>Book Of Love
# 1957<SEP>TRJFDUJ12903CA0667<SEP>The Monotones<SEP>Book of Love
# 1957<SEP>TRMCXIZ12903CB0B64<SEP>The Norman Luboff Choir<SEP>Tender Love
# 1958<SEP>TRSBBSU12903CAC212<SEP>Ahmad Jamal<SEP>No Greater Love
# 1958<SEP>TRBPQIF128F145696D<SEP>Buddy Holly<SEP>I'm Gonna Love You Too
# 1958<SEP>TRVIEJI128F9317FFD<SEP>Chantels<SEP>I Love You So
# 1958<SEP>TRYEQLG128F931F9C3<SEP>Chordettes<SEP>I'd Love To Live In Loveland
# 1958<SEP>TRHADMS128F9347D1E<SEP>Elizabeth Cotten<SEP>I don't love nobody
# 1958<SEP>TRGJKKX12903CBECB6<SEP>Esquivel<SEP>My Number One Love
# 1958<SEP>TRGXOJY12903CBECDC<SEP>Esquivel<SEP>I Love Paris
# 1958<SEP>TRGPUOQ128F9303F98<SEP>JOHN COLTRANE<SEP>Like Someone In Love
# 1958<SEP>TRSHRGW128F930E2CE<SEP>Jerry Butler & The Impressions<SEP>For Your Precious Love
# 1958<SEP>TRHHRWG12903CFC088<SEP>Johnny Cash<SEP>The Ways of a Woman In Love
# 1958<SEP>TRCFIFC128EF343975<SEP>Johnny Cash<SEP>The Ways Of A Woman In Love
# 1958<SEP>TRTPHKB128F933B6F7<SEP>Johnny Cash<SEP>Train Of Love
# 1958<SEP>TRLWSMM128F93368A1<SEP>Johnny Cash<SEP>Train Of Love
# 1958<SEP>TRHDHWW128F93492B8<SEP>Muddy Waters<SEP>I Just Want To Make Love To You
# 1958<SEP>TRPLEFM128EF349728<SEP>Muddy Waters<SEP>I Just Want To Make Love To You
# 1958<SEP>TRWDDNY128F9300ABB<SEP>Otis Rush<SEP>All Your Love (I Miss Loving)
# 1958<SEP>TRQKMAI128F932CF74<SEP>Otis Rush<SEP>All Your Love (I Miss Loving)
# 1958<SEP>TRJADTL128F930EBC9<SEP>Otis Rush<SEP>All Your Love (I Miss Loving)
# 1958<SEP>TRGLJPC128F149E9EB<SEP>The Chantels<SEP>I Love You So
# 1958<SEP>TRRZSDS128F149E9EF<SEP>The Chantels<SEP>Sure Of Love
# 1958<SEP>TRUGBYA12903CD573B<SEP>The Chantels<SEP>I Love You So
# 1958<SEP>TRWQYOX128F424BEAB<SEP>The Impressions<SEP>For Your Precious Love
# 1958<SEP>TRGMVZJ128F1466B38<SEP>The King Sisters<SEP>Don't Take Your Love From Me
# 1958<SEP>TRGKYIR128F93010A3<SEP>The Teddy Bears<SEP>To Know Him Is To Love Him
# 1958<SEP>TROFBYC128F92FA236<SEP>The Teddy Bears<SEP>To Know Him Is To Love Him
# 1958<SEP>TRYQUQA128F932E152<SEP>The Teddy Bears<SEP>To Know Him Is To Love Him
# 1959<SEP>TRXODBR128F1498F5B<SEP>Blossom Dearie<SEP>It's Love
# 1959<SEP>TRXKQPO12903CD7611<SEP>Bobby Darin<SEP>That's The Way Love Is
# 1959<SEP>TRUOKVM128F931AF25<SEP>Chico Leverett<SEP>I'll Never Love Again
# 1959<SEP>TRNHHCK12903CAADF3<SEP>Dean Martin<SEP>I've Got My Love To Keep Me Warm
# 1959<SEP>TRIKLPV12903CB39CD<SEP>Dion & The Belmonts<SEP>A Teenager In Love
# 1959<SEP>TRPXQGF128F1467DF2<SEP>Dion & The Belmonts<SEP>A Teenager In Love
# 1959<SEP>TRJDDWF128F93011D9<SEP>Dion & The Belmonts<SEP>A Teenager In Love
# 1959<SEP>TRLZJNM128F930E168<SEP>Dion And The Belmonts<SEP>A Teenager In Love
# 1959<SEP>TRIVCYI128F9330A5E<SEP>Dolly Parton<SEP>Puppy Love
# 1959<SEP>TRWCPIF128F92FDC45<SEP>Dolly Parton & Lynn Anderson<SEP>Puppy Love
# 1959<SEP>TRHDPDW128F931F927<SEP>Elvis Presley<SEP>I Need Your Love Tonight
# 1959<SEP>TRQLZEC128F42A22C6<SEP>Elvis Presley<SEP>A Big Hunk O' Love
# 1959<SEP>TRDXXNZ128F145B2C2<SEP>Frank Sinatra<SEP>The One I Love (Belongs To Somebody Else)
# 1959<SEP>TRLXPSU128F92F0183<SEP>Harold Dorman<SEP>Mountain Of Love
# 1959<SEP>TRPKCHC128F1453DAE<SEP>Harvey & The Moonglows<SEP>Ten Commandments Of Love
# 1959<SEP>TRHUBPB12903CFB6A9<SEP>Jackie Wilson<SEP>We Have Love
# 1959<SEP>TRHLCIL12903CF1733<SEP>Jackie Wilson<SEP>That's Why (I Love You So)
# 1959<SEP>TRCFDVC128F931FB33<SEP>Jackie Wilson<SEP>We Have Love
# 1959<SEP>TRRPDLM12903CB7345<SEP>Jackie Wilson<SEP>That's Why (I Love You So)
# 1959<SEP>TRAXXJZ12903CF1731<SEP>Jackie Wilson<SEP>Each Time (I Love You More)
# 1959<SEP>TRNTVWR128F92D41C5<SEP>Jimmy Clanton<SEP>Losing The One I Love
# 1959<SEP>TRTKLPZ128F92CA280<SEP>Jimmy Reed<SEP>Signals Of Love - Original
# 1959<SEP>TRKSPUF128F92E5356<SEP>John Lee Hooker<SEP>I love you honey
# 1959<SEP>TRDKAQR128F92EB1FB<SEP>Johnny Cash<SEP>Straight A's In Love
# 1959<SEP>TROQKNB128F9327F68<SEP>Johnny Cash<SEP>Straight A's In Love
# 1959<SEP>TRYJEBD128F92DDE2D<SEP>Johnny Cash<SEP>Straight A's in Love
# 1959<SEP>TRDIINP128F4268DD6<SEP>Johnny Horton<SEP>All For The Love Of A Girl
# 1959<SEP>TRVRRBD12903CE9B5A<SEP>Julie London<SEP>When I Fall In Love
# 1959<SEP>TRTBLEG12903CA1289<SEP>Mantovani<SEP>Secret Love
# 1959<SEP>TRRWVKG128F93524C5<SEP>Petula Clark<SEP>I Love a Violin
# 1959<SEP>TROPIEV12903CDC783<SEP>Petula Clark<SEP>I Love A Violin
# 1959<SEP>TRMPEGE12903CC5F5D<SEP>Sam Cooke<SEP>Win Your Love For Me
# 1959<SEP>TRRPEBD12903CF1892<SEP>Sam Cooke<SEP>Win Your Love For Me
# 1959<SEP>TRUFKGN12903CE0634<SEP>Sarah Vaughan<SEP>The Man I Love
# 1959<SEP>TRUXMYL128F426A4A6<SEP>Shirley Bassey<SEP>I've Never Been In Love Before
# 1959<SEP>TRJFBCX12903CB3ACB<SEP>Shirley Bassey<SEP>As I Love You
# 1959<SEP>TRMKPXG128F4249D52<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRWXOZU128F92DEC51<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRGAZBF12903CA904C<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRZZKOS128F92F9074<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRZKMRS128F9339878<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRNSLIX128F93590A6<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRLIKCO128F424B242<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRLAQSH128F9322576<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRXIVCO128F931D863<SEP>Sonny James<SEP>young love
# 1959<SEP>TRYSVIV12903CFB1F5<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRYXWJJ128F1494B02<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRYXBYW12903C93D7A<SEP>Sonny James<SEP>Young Love
# 1959<SEP>TRLARLT128F9325BFD<SEP>The Flamingos<SEP>I'm In The Mood For Love
# 1959<SEP>TRGEEUG128F1466B3F<SEP>The King Sisters<SEP>There Is No Greater Love
# 1959<SEP>TRNSTYV128F92C9712<SEP>Wynton Kelly<SEP>Make The Man Love Me
# 1960<SEP>TRDNHON128F92CB2AD<SEP>Arthur Big Boy Crudup<SEP>I Love Her Just The Same
# 1960<SEP>TRLUMJX128F92F691F<SEP>Bo Diddley<SEP>I Love You So
# 1960<SEP>TREGNWO128F4222D7D<SEP>Brenda Lee<SEP>Once Love Makes A Fool Of You (LP Version)
# 1960<SEP>TRTQWAT128F42596D8<SEP>Buddy Holly<SEP>True Love Ways
# 1960<SEP>TRKRMTD128F145D521<SEP>Cliff Richard And The Shadows<SEP>I Love You
# 1960<SEP>TRFLPXO128F428F5A7<SEP>Elvis Presley<SEP>Tonight Is So Right For Love
# 1960<SEP>TRMSGFD128F4233F1A<SEP>Eric Dolphy<SEP>Reincarnation Of A Love Bird (Take 1)
# 1960<SEP>TRCFPJF128F428A872<SEP>Etta James<SEP>I Just Want To Make Love To You
# 1960<SEP>TROCESW128F92FCFE5<SEP>Etta Jones<SEP>I Love Paris
# 1960<SEP>TRGDSEQ128F9314176<SEP>JERRY WALLACE<SEP>You're Singing Our Love Song To Somebody Else
# 1960<SEP>TRWSWFL128F4263FFD<SEP>Jimmy Reed<SEP>Found Love
# 1960<SEP>TRHXDVN128F4224754<SEP>Jimmy Reed<SEP>Found Love
# 1960<SEP>TRWINCB128F936351C<SEP>Johnny Cash<SEP>Give my Love to Rose
# 1960<SEP>TRDAUBO128F429F063<SEP>Johnny Cash<SEP>Give My Love To Rose
# 1960<SEP>TRAIJFX128F92DE671<SEP>Johnny Cash;June Carter<SEP>Give My Love To Rose
# 1960<SEP>TRHLRPS12903CC5E56<SEP>Little Anthony & The Imperials<SEP>I'm Still In Love With You
# 1960<SEP>TRIUDOX128F14A563A<SEP>Little Anthony and The Imperials<SEP>I'm Still In Love With You
# 1960<SEP>TRBROTX128F935EB5C<SEP>Marv Johnson<SEP>I Love The Way You Love
# 1960<SEP>TRNWMQX128F9339D70<SEP>Marv Johnson<SEP>I Love The Way You Love
# 1960<SEP>TRQWDIW12903CD571A<SEP>Paul Anka<SEP>Crazy Love
# 1960<SEP>TRZFYYM12903CE1A12<SEP>Paul Anka<SEP>I Love You Baby
# 1960<SEP>TRITMCG12903CDFB35<SEP>Paul Anka<SEP>That's Love
# 1960<SEP>TREKRFQ12903CF4F6F<SEP>Paul Anka<SEP>I Love You Baby
# 1960<SEP>TRDGPEG12903CFAA7B<SEP>Paul Anka<SEP>I Love You Baby
# 1960<SEP>TRXNNED128F92E1923<SEP>Shirelles<SEP>Dedicated To The One I Love
# 1960<SEP>TRQDUXT128F149E9F4<SEP>The Chantels<SEP>Goodbye To Love
# 1960<SEP>TREGQPZ12903C9C9A7<SEP>The Everly Brothers<SEP>Made To Love
# 1960<SEP>TRMXWPI128F935A32F<SEP>The Shirelles<SEP>Dedicated To the One I Love
# 1960<SEP>TRWBZAX128F92FE876<SEP>The Shirelles<SEP>Dedicated To The One I Love
# 1960<SEP>TRAHBWE128F9349247<SEP>The Shirelles<SEP>Dedicated To The One I Love
# 1960<SEP>TRAAYGH128F92ECD16<SEP>The Shirelles<SEP>Will You Love Me Tomorrow
# 1960<SEP>TRPPAPQ128F92F1375<SEP>The Shirelles<SEP>Dedicated To The One I Love
# 1960<SEP>TRTEMVY12903CBE445<SEP>The Shirelles<SEP>Will You Love Me Tomorrow
# 1960<SEP>TRUYQXZ12903CB4DB3<SEP>The Shirelles<SEP>Dedicated To The One I Love
# 1960<SEP>TRJDSEQ12903C97129<SEP>The Shirelles<SEP>Dedicated To The One I Love
# 1960<SEP>TRJKLDW128F93291F1<SEP>The Shirelles<SEP>Will You Love Me Tomorrow
# 1960<SEP>TRSSKLW128F92EF99C<SEP>The Shirelles<SEP>Dedicated To the One I Love
# 1960<SEP>TRDNLHI128F9311F22<SEP>The Shirelles<SEP>Dedicated To the One I Love
# 1961<SEP>TRKQXQE12903CEBEBF<SEP>April Stevens<SEP>I'm In Love Again
# 1961<SEP>TRGIJND128F42759D7<SEP>Ben E. King<SEP>Love Me_ Love Me (LP Version)
# 1961<SEP>TRWQVNV128F425E66F<SEP>Carla Thomas<SEP>Fools Fall In Love (LP Version)
# 1961<SEP>TRWOZFS128F425E677<SEP>Carla Thomas<SEP>The Love We Shared (LP Version)
# 1961<SEP>TRNQYDA128F423DEB9<SEP>Carla Thomas<SEP>A Love Of My Own  (Single/LP Version)
# 1961<SEP>TRGEKBZ12903CC1C5A<SEP>Del Shannon<SEP>I'll Always Love You
# 1961<SEP>TRBZPDE12903CE1AB9<SEP>Ella Fitzgerald<SEP>I Am In Love
# 1961<SEP>TRQHJAK128F428F2D0<SEP>Elvis Presley<SEP>Can't Help Falling In Love
# 1961<SEP>TRYBALZ128F92F12BD<SEP>Elvis Presley<SEP>Can't Help Falling In Love
# 1961<SEP>TRINCVS128E0790966<SEP>Faron Young<SEP>Live Fast_ Love Hard_ Die Young
# 1961<SEP>TRHAIYG128F933E364<SEP>Faye Adams<SEP>Your Love (Has My Heart Burnin)
# 1961<SEP>TRQHJIT128F429FB44<SEP>Hank Thompson<SEP>I Dreamed Of An Old Love Affair
# 1961<SEP>TRPOJCK128F92FDCD9<SEP>Ike And Tina Turner<SEP>A Fool In Love
# 1961<SEP>TREUCZF128F1480CF5<SEP>Ike And Tina Turner<SEP>The Way You Love Me
# 1961<SEP>TRYDRVK12903CAE648<SEP>John Leyton<SEP>You Took My Love for Granted
# 1961<SEP>TRLJVPG128F92F885C<SEP>Junior Parker<SEP>I Need Love So Bad
# 1961<SEP>TRERRND128EF34DC40<SEP>Little Junior Parker<SEP>I Need Love So Bad
# 1961<SEP>TRDHLQV128F930336C<SEP>Nat King Cole<SEP>Let There Be Love
# 1961<SEP>TRUIEFD12903CE3776<SEP>Nina Simone<SEP>Just Say I Love Him (2004 Digital Remaster)
# 1961<SEP>TRZEUYC128F427CD36<SEP>The Louvin Brothers<SEP>Childish Love
# 1961<SEP>TRWJGGN128F1457EA3<SEP>Timi Yuro<SEP>All My Love Belongs To You
# 1962<SEP>TRNZXJC128F4265955<SEP>Bobby Vinton<SEP>I Love You The Way You Are
# 1962<SEP>TRJUVYH128F426A437<SEP>Dean Martin<SEP>My One And Only Love
# 1962<SEP>TRJXVSV128F14945AE<SEP>Dean Martin<SEP>(I Love You) For Sentimental Reasons (1998 Digital Remaster)
# 1962<SEP>TRIUJKJ128F4269B1A<SEP>Frank Ifield<SEP>The Glory Of Love
# 1962<SEP>TRLSFAP128F4269B25<SEP>Frank Ifield<SEP>In A Mansion Stands My Love (1997 Digital Remaster)
# 1962<SEP>TRMZILF128F4276436<SEP>Jerry Butler<SEP>For Your Precious Love
# 1962<SEP>TRRMXHE128E0790EC1<SEP>Jerry Butler<SEP>For Your Precious Love
# 1962<SEP>TRPORST12903CA2100<SEP>Jerry Butler<SEP>For Your Precious Love
# 1962<SEP>TRCGAQX12903CE6C8D<SEP>Jesse Belvin<SEP>Goodnight My Love
# 1962<SEP>TRZHAFH128F92E1069<SEP>Jesse Belvin<SEP>Goodnight My Love
# 1962<SEP>TRIGTPM12903CEB1E5<SEP>Jesse Belvin<SEP>Goodnight My Love
# 1962<SEP>TRVFECL128F9355896<SEP>Jesse Belvin<SEP>Goodnight My Love
# 1962<SEP>TROSPJG128F92E1041<SEP>Jesse Belvin<SEP>Goodnight My Love
# 1962<SEP>TRYMJPP128F9310C8A<SEP>Joey Dee & The Starliters<SEP>What Kind Of Love Is This
# 1962<SEP>TRATUED128F931B027<SEP>Mary Wells<SEP>Old Love (Let's Try It Again)
# 1962<SEP>TRPYIBD128F931B028<SEP>Mary Wells<SEP>Old Love (Let's Try It Again)
# 1962<SEP>TRNMWQY128F14984B8<SEP>McCoy Tyner<SEP>There Is No Greater Love
# 1962<SEP>TRWTRZC12903CEB8F3<SEP>The Contours<SEP>Do You Love Me
# 1962<SEP>TRGTFXV128F42BAE23<SEP>The Contours<SEP>Do You Love Me
# 1962<SEP>TRQSDBL128F92DE0A9<SEP>The Contours<SEP>Do You Love Me
# 1962<SEP>TRTPXWT128F92FE179<SEP>The Contours<SEP>Do You Love Me
# 1962<SEP>TRECSKT128F931B098<SEP>The Contours<SEP>It Must Be Love
# 1962<SEP>TRJCXLB128F421493D<SEP>The Contours<SEP>Do You Love Me
# 1962<SEP>TRJXOMF12903CE699E<SEP>The Contours<SEP>Do You Love Me
# 1962<SEP>TREJRGN128F92F4551<SEP>The Contours with Joe Billingslea<SEP>Do You Love Me
# 1962<SEP>TRCYMES12903C9FE94<SEP>The Crystals<SEP>I Love You Eddie
# 1962<SEP>TRZAVQJ128F92D328F<SEP>The Everly Brothers<SEP>True Love
# 1962<SEP>TROGOED128F9325BD5<SEP>The Flamingos<SEP>Flame Of Love
# 1962<SEP>TRIPLJR12903C9C77B<SEP>The Mar-Keys<SEP>Cause I Love You
# 1962<SEP>TRWXMQS128F428CD0C<SEP>The Spotnicks<SEP>Harmour Love
# 1962<SEP>TRRAPDZ128F429B5D2<SEP>The Teen Queens<SEP>Eddie My Love
# 1962<SEP>TRURWXU12903CEC12B<SEP>The Teen Queens<SEP>Eddie My Love
# 1962<SEP>TRSOEYY128F931D8BB<SEP>The Teen Queens<SEP>Eddie My Love
# 1962<SEP>TRVIXRY12903CE6610<SEP>The Teen Queens<SEP>Eddie My Love
# 1962<SEP>TRDHNWK12903CA9025<SEP>The Teen Queens<SEP>Eddie My Love
# 1962<SEP>TRDXHTD128F93540C3<SEP>The Teen Queens<SEP>Eddie My Love
# 1962<SEP>TRWKJYQ128F93491DF<SEP>The Teenqueens<SEP>Eddie My Love
# 1962<SEP>TRICBPG128F92EAB63<SEP>Tony Bennett<SEP>Taking A Chance On Love
# 1962<SEP>TRSGPYH12903D02694<SEP>Tony Bennett<SEP>Taking a Chance On Love
# 1963<SEP>TRXYWAW128F423423B<SEP>Betty Everett<SEP>Chained To Your Love
# 1963<SEP>TRCECGK128F92E6FC5<SEP>Bill Evans Trio<SEP>Like Someone In Love
# 1963<SEP>TRZGMGD12903CBC775<SEP>Billy Boy Arnold<SEP>I Love Only You
# 1963<SEP>TRDZZUL12903CBC776<SEP>Billy Boy Arnold<SEP>You Don't Love Me No More
# 1963<SEP>TRBPTKV12903CD38C2<SEP>Bobby Bare<SEP>Book Of Love
# 1963<SEP>TRWKRFN12903CD6413<SEP>Chuck Berry<SEP>I Just Want To Make Love To You
# 1963<SEP>TRQEQDT128F14989F7<SEP>Crystals<SEP>He's Sure The Boy I Love
# 1963<SEP>TROKBIH12903CAB72D<SEP>Fourmost<SEP>I'm In Love
# 1963<SEP>TRGXEII128F92F3E4D<SEP>John Coltrane / Johnny Hartman<SEP>My One And Only Love
# 1963<SEP>TRSFIJQ128F423B4DE<SEP>John Coltrane / Johnny Hartman<SEP>My One And Only Love
# 1963<SEP>TRDVNPT128F149A19B<SEP>John Coltrane / Johnny Hartman<SEP>My One And Only Love
# 1963<SEP>TRANXVW128F9310399<SEP>John Coltrane Quartet<SEP>You Don't Know What Love Is
# 1963<SEP>TRLUSKP128F14AEA61<SEP>John Coltrane Quartet<SEP>You Don't Know What Love Is
# 1963<SEP>TRSPGEU128F149A1A0<SEP>John Coltrane Quartet<SEP>You Don't Know What Love Is
# 1963<SEP>TRMGDWY12903CFA965<SEP>Mary Wells<SEP>Old Love
# 1963<SEP>TRBRBWM128F93227CF<SEP>Mary Wells<SEP>What Love Has Joined Together
# 1963<SEP>TRYTASK128F931F7A8<SEP>Mary Wells<SEP>(I Guess There's) No Love
# 1963<SEP>TREXFUL128F92F2B58<SEP>Mongo Santamaria<SEP>Love_ Oh Love
# 1963<SEP>TRCJHGT12903CD9B3E<SEP>Sam Cooke<SEP>(I Love You) for Sentimental Reasons
# 1963<SEP>TRNOUJE128E078A44D<SEP>Sam Cooke<SEP>(I Love You) For Sentimental Reasons
# 1963<SEP>TRZZWWZ12903C9FE8B<SEP>The Crystals<SEP>He's Sure The Boy I Love
# 1963<SEP>TRIWKIE128F92F0186<SEP>The Crystals<SEP>He's Sure The Boy I Love
# 1963<SEP>TRUINNO12903CC58E7<SEP>The Crystals<SEP>He's sure the boy I love
# 1963<SEP>TRYGSXK128F429179D<SEP>The Crystals<SEP>He's Sure the Boy I Love
# 1963<SEP>TRDNFMG12903CFB75E<SEP>The Crystals / Darlene Love<SEP>He's Sure The Boy I Love
# 1963<SEP>TRQNIQK128E078E00E<SEP>The Fourmost<SEP>I'm In Love
# 1963<SEP>TRTBQZN128F148B777<SEP>The Raindrops<SEP>Isn't That Love
# 1963<SEP>TRWVOHQ128F427C3C8<SEP>The Rivingtons<SEP>Standing In The Love Line
# 1963<SEP>TRVMDMB128F427C3C6<SEP>The Rivingtons<SEP>Old Time Love
# 1963<SEP>TRUYOTG128EF349A07<SEP>The Supremes<SEP>Standing At The Crossroads Of Love
# 1963<SEP>TREVKND128EF34994E<SEP>The Temptations<SEP>I Want A Love I Can See
# 1963<SEP>TRQDDYK12903D083DE<SEP>The Tremeloes<SEP>Do You Love Me
# 1963<SEP>TRMWWDG128F9328575<SEP>Vince Guaraldi<SEP>The Love Of A Rose
# 1963<SEP>TRAEJRM128F4260771<SEP>Wanda Jackson<SEP>Pledging My Love
# 1963<SEP>TRMOHYM12903CEB8FC<SEP>Wilson Pickett<SEP>I'm Gonna Love You
# 1963<SEP>TRNKJDK128F92D4512<SEP>Wilson Pickett<SEP>I'm Gonna Love You
# 1963<SEP>TRPSOVK128F933F927<SEP>Wilson Pickett<SEP>I'm Gonna Love You
# 1963<SEP>TREDMSH128E0790C6E<SEP>Wilson Pickett<SEP>I'm Gonna Love You
# 1963<SEP>TROCAYQ12903CD9ED7<SEP>Wilson Pickett<SEP>I'm Gonna Love You
# 1964<SEP>TRRWZPR128F933E257<SEP>B.B. King<SEP>Please Accept My Love
# 1964<SEP>TRQGZAX12903CEA94D<SEP>B.B. King<SEP>Please Accept My Love
# 1964<SEP>TRPIMHB128E0790AD7<SEP>Betty Everett<SEP>It Hurts To Be In Love
# 1964<SEP>TRKXMBT128F9311084<SEP>Brenda Holloway<SEP>A Favor For A Girl (With A Love Sick Heart)
# 1964<SEP>TRWJXKW128F92D86B8<SEP>Chad & Jeremy<SEP>Too Soon My Love
# 1964<SEP>TRRJRGO128F92D86D7<SEP>Chad & Jeremy<SEP>Like I Love You Today
# 1964<SEP>TRBMFEE128F93028FE<SEP>Chad & Jeremy<SEP>Like I Love You Today
# 1964<SEP>TRPTQIA128F93028DE<SEP>Chad & Jeremy<SEP>Too Soon My Love
# 1964<SEP>TRJWYER128F933D9FF<SEP>Chad & Jeremy<SEP>Too Soon My Love
# 1964<SEP>TREGGON128F1499543<SEP>Ella Fitzgerald<SEP>Can't Buy Me Love
# 1964<SEP>TREMJCL128F1484AB4<SEP>Irma Thomas<SEP>Anyone Who Knows What Love Is (Will Understand)
# 1964<SEP>TRHPFER128F92F20C1<SEP>John Hammond<SEP>I Live The Life I Love
# 1964<SEP>TRXFVUG128F92FE9DF<SEP>John Hammond<SEP>Who Do You Love (Alternate version)
# 1964<SEP>TRRBJMF128F1499BD5<SEP>Johnny Hartman<SEP>How Sweet It Is To Be In Love
# 1964<SEP>TRFGAYI128F424DF2E<SEP>Johnny Hartman<SEP>How Sweet It Is To Be In Love
# 1964<SEP>TRIPUHG128F1499BD4<SEP>Johnny Hartman<SEP>Don't Call It Love
# 1964<SEP>TRUUNHP128F424DF2D<SEP>Johnny Hartman<SEP>Don't Call It Love
# 1964<SEP>TRWIJZV128F14970CB<SEP>Judy Henske<SEP>You Are Not My First Love  (LP Version)
# 1964<SEP>TRVRZXQ128F92D5BC7<SEP>Lesley Gore<SEP>Look Of Love
# 1964<SEP>TRMLAXQ128E0783673<SEP>Lorez Alexandria<SEP>My One And Only Love
# 1964<SEP>TRGZMUR128E0783671<SEP>Lorez Alexandria<SEP>I've Never Been In Love Before
# 1964<SEP>TRQMQMR128F4271EFF<SEP>Lorez Alexandria<SEP>I'm Through With Love
# 1964<SEP>TRUGWNB128E0783679<SEP>Lorez Alexandria<SEP>I'm Through With Love
# 1964<SEP>TRHPYRQ128F145F07C<SEP>Peggy Lee<SEP>In The Name Of Love
# 1964<SEP>TROKYVE128F1461E5D<SEP>Peter And Gordon<SEP>A World Without Love
# 1964<SEP>TRXKNLX128F92D2CF2<SEP>Peter And Gordon<SEP>A World Without Love
# 1964<SEP>TRNUWTX128F14904F4<SEP>The Applejacks<SEP>Three Little Words (I Love You)
# 1964<SEP>TRLXJLX128F429EF2F<SEP>The Bee Gees<SEP>Three Kisses Of Love
# 1964<SEP>TRGWVXK12903CEBA65<SEP>The Dixie Cups<SEP>Chapel of Love
# 1964<SEP>TREPITR12903CC2201<SEP>The Dixie Cups<SEP>Chapel Of Love
# 1964<SEP>TRXAAJE128F92EF993<SEP>The Dixie Cups<SEP>Chapel of Love
# 1964<SEP>TRCRKMV128F42952D2<SEP>The Hollies<SEP>Do You Love Me
# 1964<SEP>TRFNDHJ128F145275D<SEP>The Marvelettes<SEP>A Need For Love
# 1964<SEP>TRZTTYO128F421CC15<SEP>The Searchers<SEP>Don't Throw Your Love Away
# 1964<SEP>TRNIEPI128F421CC1C<SEP>The Searchers<SEP>Goodbye My Love
# 1964<SEP>TRQMWPZ128F424840F<SEP>The Shangri-Las<SEP>So Much In Love (Live)
# 1964<SEP>TRTAEUM128F934630F<SEP>The Shangri-Las<SEP>So Much in Love
# 1964<SEP>TRUENYE128E078FEB5<SEP>The Supremes<SEP>Baby Love
# 1964<SEP>TRUXBQR128EF349A44<SEP>The Supremes<SEP>Where Did Our Love Go
# 1964<SEP>TRLCTIH12903CE3085<SEP>The Yardbirds<SEP>Got Love If You Want It
# 1965<SEP>TRGZNMO12903CA6001<SEP>Bert Jansch<SEP>Harvest Your Thoughts Of Love
# 1965<SEP>TREATID128F93501D2<SEP>Buddy Holly / The Fireballs<SEP>Baby It's Love
# 1965<SEP>TRGTTLZ128F92D86C2<SEP>Chad & Jeremy<SEP>Only Those In Love
# 1965<SEP>TREFUQQ128F149E853<SEP>Duke Pearson<SEP>Our Love (LP Version)
# 1965<SEP>TRHYWGK128F9309C33<SEP>Frank Wilson<SEP>Do I Love You (Indeed I Do)
# 1965<SEP>TRPAAXW128F9351DA8<SEP>Frank Wilson<SEP>Do I Love You (Indeed I Do)
# 1965<SEP>TRDAIJL128E07811BD<SEP>Frank Wilson<SEP>Do I Love You (Indeed I Do)
# 1965<SEP>TRMUQHK128F1499B91<SEP>Johnny Hartman<SEP>Let Me Love You
# 1965<SEP>TRAANTZ128F92EAEA6<SEP>Lee Dorsey<SEP>Take Care Of Our Love
# 1965<SEP>TRJDKQV128F92EAE9D<SEP>Lee Dorsey<SEP>The Greatest Love
# 1965<SEP>TRKLEKJ128F1452915<SEP>Marianne Faithfull<SEP>If I Never Get To Love You
# 1965<SEP>TRQNGQK12903CD2B0B<SEP>Otis Redding<SEP>That's How Strong My Love Is
# 1965<SEP>TRLRXIO128F4276276<SEP>Otis Redding<SEP>Nothing Can Change This Love
# 1965<SEP>TREXAOI128F4276279<SEP>Otis Redding<SEP>For Your Precious Love
# 1965<SEP>TRVVBQD12903CAF5ED<SEP>Otis Redding<SEP>For Your Precious Love
# 1965<SEP>TRSFMJB128F428D473<SEP>Sonny Rollins<SEP>My One And Only Love
# 1965<SEP>TRYDRQQ128F931798E<SEP>Sonny Rollins<SEP>My One And Only Love
# 1965<SEP>TROGEFG128F1485134<SEP>The Beach Boys<SEP>Summer Means New Love
# 1965<SEP>TRQKVRI128E078E010<SEP>The Fourmost<SEP>I Love You Too
# 1965<SEP>TRVDNUM128F931B47E<SEP>The Paul Butterfield Blues Band<SEP>Our Love Is Drifting (LP Version)
# 1965<SEP>TRHSJLQ128F428CFC0<SEP>The Ronettes<SEP>Recipe For Love
# 1965<SEP>TRRXCRX128F42BB336<SEP>The Sonics<SEP>Have Love Will Travel
# 1965<SEP>TRMHPCB128F426C549<SEP>The Strangeloves<SEP>Rhythm Of Love
# 1965<SEP>TRJJPRJ128F426C544<SEP>The Strangeloves<SEP>Sendin' My Love
# 1965<SEP>TRMQPHH128E0792D17<SEP>The Temptations<SEP>What Love Has Joined Together
# 1965<SEP>TRRFWEV128F930DD91<SEP>The Yardbirds<SEP>For Your Love
# 1965<SEP>TRURYTO128F931C679<SEP>The Yardbirds<SEP>For Your Love
# 1965<SEP>TRRHSWB12903D0AF7A<SEP>The Zombies<SEP>I Love You
# 1966<SEP>TRMUHAI128F428DE44<SEP>Big Mama Thornton<SEP>I Need Your Love
# 1966<SEP>TRDXPTD128F428DE39<SEP>Big Mama Thornton<SEP>Your Love Is Where It Ought To Be
# 1966<SEP>TRPODNB128E0791D03<SEP>Bobby Moore & The Rhythm Aces<SEP>Searching For My Love
# 1966<SEP>TRJJIZH128F92F6250<SEP>Bobby Moore & The Rhythm Aces<SEP>Searching For My Love
# 1966<SEP>TREAQAX128F92FA595<SEP>Buffy Sainte-Marie<SEP>Timeless Love
# 1966<SEP>TRAWOMV128F423748B<SEP>Carla Thomas<SEP>Medley: Baby What You Want Me To Do / For Your Love
# 1966<SEP>TRUTGUW128F423748F<SEP>Carla Thomas<SEP>You Don't Have To Say You Love Me (LP Version)
# 1966<SEP>TRQVAGW128F1494C72<SEP>Cat Stevens<SEP>I've Found A Love
# 1966<SEP>TRVCAXD128F1463478<SEP>Cat Stevens<SEP>I've Found A Love
# 1966<SEP>TRMQPDM128F9316D29<SEP>Coleman Hawkins<SEP>And I Still Love You
# 1966<SEP>TRGHCPG128F92E9D89<SEP>David Houston<SEP>Living In A House Full Of Love
# 1966<SEP>TRCTODI128F92E9D85<SEP>David Houston<SEP>Where Love Used To Be
# 1966<SEP>TRQNHOO128F92E9D83<SEP>David Houston<SEP>I'm Down To My Last "I Love You
# 1966<SEP>TRDRKUK12903CB50DA<SEP>David Houston<SEP>Livin' In A House Full Of Love
# 1966<SEP>TRXYKQO128F92E9D86<SEP>David Houston<SEP>Mountain Of Love
# 1966<SEP>TRAHLWR128E0789609<SEP>Donovan<SEP>Preachin' Love (2005 Digital Remaster) (Mono)
# 1966<SEP>TRZPYAQ128F92D9A68<SEP>Eddie Bo<SEP>Let Our Love Begin
# 1966<SEP>TRFKVJO128F93225C9<SEP>Engelbert Humperdinck<SEP>How Near Is Love
# 1966<SEP>TRLQRBX128F9319116<SEP>Gabor Szabo<SEP>The Echo Of Love
# 1966<SEP>TRRWLVN128F92F60A0<SEP>Herb Alpert And The Tijuana Brass<SEP>What Now My Love
# 1966<SEP>TRALKHT128F148833B<SEP>John Mayall & The Bluesbreakers<SEP>All Your Love
# 1966<SEP>TRTMCPB128F1488350<SEP>John Mayall & The Bluesbreakers<SEP>Key To Love
# 1966<SEP>TRMDMMK128F4299625<SEP>Lena Horne<SEP>I Love Paris
# 1966<SEP>TRAMKFS128F4277993<SEP>Marvin Gaye<SEP>Your Unchanging Love
# 1966<SEP>TRIPMEU128F149CB15<SEP>Marvin Gaye / Kim Weston<SEP>Secret Love
# 1966<SEP>TRBLQEV128F4230DFA<SEP>Mitch Ryder & The Detroit Wheels<SEP>Let Your Love Light Shine  (LP Version)
# 1966<SEP>TRMKHAW128F427D459<SEP>Nancy Sinatra<SEP>If He'd Love Me
# 1966<SEP>TRLGXPS128F428099E<SEP>Percy Sledge<SEP>Good Love
# 1966<SEP>TRUYRMT128F930D534<SEP>Perrey And Kingsley<SEP>Computer In Love
# 1966<SEP>TRKHOAG128F9302DDA<SEP>Perrey And Kingsley<SEP>Computer In Love
# 1966<SEP>TRFBZPS128F93599D6<SEP>Ronnie Dove<SEP>Mountain Of Love
# 1966<SEP>TRTJUTE12903CC4BBE<SEP>Sandy Posey<SEP>Put A Little Love In Your Heart
# 1966<SEP>TREBNCU128F92E8C7E<SEP>Sandy Posey<SEP>What A Woman In Love Won't Do
# 1966<SEP>TROCJRH12903CC4BAC<SEP>Sandy Posey<SEP>What A Woman In Love Won't Do
# 1966<SEP>TRJRZEQ128F9324CA7<SEP>Shirley Scott<SEP>This Love Of Mine
# 1966<SEP>TRPMMSJ128F931B306<SEP>Smokey Robinson & The Miracles<SEP>Oh Be My Love
# 1966<SEP>TRNDDKX128F1459B0C<SEP>Sonny & Cher<SEP>What Now My Love
# 1966<SEP>TRREUEY128F14962B4<SEP>Stevie Wonder<SEP>Contract On Love
# 1966<SEP>TRUWXAC12903C9A7E2<SEP>The Everly Brothers<SEP>[You Got] The Power Of Love
# 1966<SEP>TRLHUKI128F931B2C3<SEP>The Isley Brothers<SEP>There's No Love Left
# 1966<SEP>TRLTUIU128C7196684<SEP>The Isley Brothers<SEP>I Guess I'll Always Love You
# 1966<SEP>TREULJP12903CBA4E6<SEP>The Isley Brothers<SEP>Who Could Ever Doubt My Love
# 1966<SEP>TRJGGTM12903CBA4F4<SEP>The Isley Brothers<SEP>There's No Love Left
# 1966<SEP>TRHFFPN12903CBD4C5<SEP>The Knickerbockers<SEP>High On Love
# 1966<SEP>TRDMWGO128F42A8FB4<SEP>The Lovin' Spoonful<SEP>Phil's Love Theme
# 1966<SEP>TRRKCHY128F147D6A4<SEP>The Mamas & The Papas<SEP>Words Of Love
# 1966<SEP>TRLCJWL128F145682B<SEP>The Mamas & The Papas<SEP>Words Of Love
# 1966<SEP>TREZMNY128F429D84D<SEP>The Mamas & The Papas<SEP>Words Of Love
# 1966<SEP>TRIMGYM128E07848C0<SEP>The Mindbenders<SEP>A Groovy Kind Of Love
# 1966<SEP>TRPWNUE128F426BD0D<SEP>The Mindbenders<SEP>A Groovy Kind Of Love
# 1966<SEP>TRHWHIK128F425EEDF<SEP>The Seeds<SEP>Fallin' In Love
# 1966<SEP>TRMGFRB128F42AC079<SEP>The Spotnicks<SEP>The old love letters
# 1966<SEP>TRLZUON128F42AC07D<SEP>The Spotnicks<SEP>From Russia with love
# 1966<SEP>TRWVEGG128F429EF50<SEP>The Supremes<SEP>You Can't Hurry Love
# 1966<SEP>TRAWLRI128E078F99B<SEP>The Supremes<SEP>You Can't Hurry Love
# 1966<SEP>TRSGIVS12903CBD499<SEP>The West Coast Pop Art Experimental Band<SEP>If You Want This Love
# 1966<SEP>TRONXQL128F14A8C7E<SEP>Tom Rush<SEP>Who Do You Love  (LP Version)
# 1966<SEP>TREGMLH128F14B04CF<SEP>Tommy James & The Shondells<SEP>Don't Throw Our Love Away (LP Version)
# 1967<SEP>TRZAVQU128F4269A01<SEP>Aretha Franklin<SEP>I Never Loved A Man [The Way I Love You] [Stereo Version]
# 1967<SEP>TRACKDP128F9307E8E<SEP>Astrud Gilberto<SEP>The Face I Love
# 1967<SEP>TRQNLPX128F9343D35<SEP>Bill Cosby<SEP>Tell Me You Love Me
# 1967<SEP>TRCUJQF128F1463591<SEP>Burt Bacharach<SEP>What The World Needs Now Is Love
# 1967<SEP>TRIMIOW128F4241595<SEP>Burt Bacharach<SEP>The Look Of Love
# 1967<SEP>TRNMJMH128F92DCDFF<SEP>Burt Bacharach<SEP>What The World Needs Now Is Love
# 1967<SEP>TRNXDRD128F92DCE10<SEP>Burt Bacharach<SEP>The Look Of Love
# 1967<SEP>TROZKXO128E0785F87<SEP>Chris Clark<SEP>Until You Love Someone
# 1967<SEP>TRFSIUC128E07935B9<SEP>Clarence Carter / Duane Allman<SEP>The Road Of Love
# 1967<SEP>TRJPSPN128F42341AC<SEP>Darrell Banks<SEP>Our Love (Is In The Pocket) (LP Version)
# 1967<SEP>TRLZGPB128E07969F2<SEP>Dee Dee Warwick<SEP>I'm Gonna Make You Love Me
# 1967<SEP>TRKTVOV128F14A277C<SEP>Dionne Warwick<SEP>I Wish You Love (LP Version)
# 1967<SEP>TRZYLBD128E0784C3C<SEP>Dusty Springfield<SEP>The Look Of Love
# 1967<SEP>TRXDBKG128E0791F6D<SEP>Dusty Springfield<SEP>The Look Of Love
# 1967<SEP>TRKNFML128F426FA4D<SEP>Dusty Springfield<SEP>The Look Of Love
# 1967<SEP>TRPVOQF128F4255C46<SEP>Fred Neil<SEP>Please Send Me Someone To Love
# 1967<SEP>TRAIIML128F148665C<SEP>Gladys Knight & The Pips<SEP>Take Me In Your Arms And Love Me
# 1967<SEP>TRTDRXC128C71966D1<SEP>Gladys Knight & The Pips<SEP>Everybody Needs Love
# 1967<SEP>TRXMMLM128F147EC70<SEP>Harpers Bizarre<SEP>Lost My Love Today (Remastered Version)
# 1967<SEP>TRYRXCG128F147EC67<SEP>Harpers Bizarre<SEP>C'mon Love (Remastered Version)
# 1967<SEP>TREXQQL128F92F610F<SEP>Herb Alpert And The Tijuana Brass<SEP>The Love Nest
# 1967<SEP>TRROUYD128F4284F8B<SEP>Jefferson Airplane<SEP>Somebody To Love
# 1967<SEP>TRFRBVM128F4290646<SEP>Jefferson Airplane<SEP>Somebody To Love
# 1967<SEP>TRSSXNY128F425C294<SEP>Jefferson Airplane<SEP>Somebody To Love
# 1967<SEP>TRYCZVS128F930011A<SEP>Jefferson Airplane<SEP>Somebody to Love
# 1967<SEP>TRAMYNJ128F9325EE0<SEP>Jimmy Ruffin<SEP>Gonna Give Her All The Love I've Got
# 1967<SEP>TRAHEYG128F1464032<SEP>Jimmy Ruffin<SEP>Gonna Give Her All The Love I've Got
# 1967<SEP>TRDTJOM128F931B16E<SEP>Jimmy Ruffin<SEP>I Want Her Love
# 1967<SEP>TRSNRIP128F147EE5C<SEP>Johnnie Taylor<SEP>Outside Love  (LP Version)
# 1967<SEP>TRCFRSQ128E0791BDD<SEP>Julie Driscoll_ Brian Auger & The Trinity<SEP>A Kind Of Love In
# 1967<SEP>TRQYFSQ128F423C084<SEP>King Curtis<SEP>I Was Made To Love Her (LP Version)
# 1967<SEP>TRDYAUP128F423C081<SEP>King Curtis<SEP>I Never Loved A Man (The Way I Love You) (LP Version)
# 1967<SEP>TRFZGJJ128F93140F9<SEP>Matt Monro<SEP>From Russia With Love
# 1967<SEP>TRNMUES128F145D616<SEP>Matt Monro<SEP>Portrait Of My Love
# 1967<SEP>TRGZJON128F42BC1E3<SEP>Nina Simone<SEP>The Look Of Love
# 1967<SEP>TRVVBWI128F149DCEE<SEP>Nina Simone<SEP>I Love My Baby
# 1967<SEP>TRPGHJL128E078EAAC<SEP>Nirvana<SEP>I Never Had A Love Like This Before
# 1967<SEP>TRUAKNZ128E078EE65<SEP>Nirvana<SEP>Wings Of Love
# 1967<SEP>TRMNAXP128F426E3E3<SEP>Peaches & Herb<SEP>Let's Fall In Love
# 1967<SEP>TRORBUF128F4270752<SEP>Peaches & Herb<SEP>True Love
# 1967<SEP>TRGOVIW12903CEBA52<SEP>Percy Sledge<SEP>Warm and tender love
# 1967<SEP>TRZZXJE12903CD1D93<SEP>Percy Sledge<SEP>Warm and Tender Love
# 1967<SEP>TRPIWBH128F92FD93B<SEP>Percy Sledge<SEP>Warm And Tender Love
# 1967<SEP>TRTYIUA128F932B6A3<SEP>Percy Sledge<SEP>Warm And Tender Love
# 1967<SEP>TRUWKTJ128F92FC3DC<SEP>Percy Sledge<SEP>Warm and tender love
# 1967<SEP>TRYKJSO128F930DD52<SEP>Percy Sledge<SEP>Warm And Tender Love
# 1967<SEP>TRTYTNY128F1461E64<SEP>Peter And Gordon<SEP>When I Fall In Love
# 1967<SEP>TRNGXKC128F1490D6B<SEP>Savoy Brown Blues Band<SEP>Let Me Love You Baby
# 1967<SEP>TRGRAPQ128F9324CB2<SEP>Shirley Scott<SEP>What The World Needs Now Is Love
# 1967<SEP>TRWZGFI128F425AD94<SEP>Sly & The Family Stone<SEP>I Hate To Love Her
# 1967<SEP>TRQVSFD128F1486659<SEP>Smokey Robinson & The Miracles<SEP>The Love I Saw In You Was Just A Mirage
# 1967<SEP>TRIYHQX128F92D0A07<SEP>Smokey Robinson & The Miracles<SEP>My Love For You
# 1967<SEP>TRTMQSH128F145FCFF<SEP>Smokey Robinson & The Miracles<SEP>The Love I Saw In You Was Just A Mirage
# 1967<SEP>TRXHATK128F145FD00<SEP>Smokey Robinson & The Miracles<SEP>More Love
# 1967<SEP>TRAMYBO128C7196673<SEP>Stevie Wonder<SEP>I Was Made To Love Her
# 1967<SEP>TRTUQVL128F149647E<SEP>Stevie Wonder<SEP>I Was Made To Love Her
# 1967<SEP>TRBXSEO128F92EE6CB<SEP>T-Bone Walker<SEP>I'm Still in Love With You
# 1967<SEP>TRAYJPA12903CC54B4<SEP>T-Bone Walker<SEP>I'm Still In Love With You
# 1967<SEP>TRBJXPJ12903CC7933<SEP>The Association<SEP>Never My Love
# 1967<SEP>TRXAZQS128F147C6F7<SEP>The Association<SEP>Never My Love (Remastered Album Version)
# 1967<SEP>TRWBQQV128F42992A2<SEP>The Bonzo Dog Doo Dah Band<SEP>Piggy Bank Love (2007 Digital Remaster)
# 1967<SEP>TRWYRNY128F426E0D8<SEP>The Cyrkle<SEP>Our Love Affair's In Question
# 1967<SEP>TRMFIVX128F9300144<SEP>The Equals<SEP>Give Love a Try
# 1967<SEP>TRGQLRO128F4270AAB<SEP>The Intruders<SEP>A Love That's Real
# 1967<SEP>TRLKPUW12903CC160F<SEP>The Jimi Hendrix Experience<SEP>Bold As Love
# 1967<SEP>TRWZWBI128E07942C6<SEP>The Mamas & The Papas<SEP>Dedicated To The One I Love
# 1967<SEP>TRUOZKW128F429D852<SEP>The Mamas & The Papas<SEP>Dedicated To The One I Love
# 1967<SEP>TRDFGIU128E07918E2<SEP>The Mamas & The Papas<SEP>Dedicated To The One I Love
# 1967<SEP>TRUGAUP128F425977F<SEP>The Marvelettes<SEP>When You're Young And In Love
# 1967<SEP>TRFSANO128F931B235<SEP>The Spinners<SEP>I'll Always Love You
# 1967<SEP>TRGAUSR128F14A4311<SEP>The Temptations<SEP>Save My Love For A Rainy Day
# 1967<SEP>TRFGIPH128F42149EB<SEP>The Temptations<SEP>Two Sides To Love
# 1967<SEP>TRPHBNX12903CBD4B1<SEP>The Turtles<SEP>Grim Reaper Of Love
# 1967<SEP>TRBSLLY128F1492873<SEP>The West Coast Pop Art Experimental Band<SEP>If You Want This Love (Album Version)
# 1967<SEP>TRGGKLB128F147C6E8<SEP>Wilson Pickett<SEP>Everybody Needs Somebody To Love (LP Version)
# 1967<SEP>TRLSACM128F4255559<SEP>Wilson Pickett<SEP>I Found A Love - Part II [Single Version]
# 1968<SEP>TRWKMDC128F4215E49<SEP>Albert Ayler<SEP>Heart Love
# 1968<SEP>TRPMLRS128F4290694<SEP>Albert King<SEP>Please Love Me
# 1968<SEP>TRNQDUB128F9343E2E<SEP>Betty Wright<SEP>Funny How Love Grows Cold (Album Version)
# 1968<SEP>TRTEYSO128F9343E38<SEP>Betty Wright<SEP>Watch Out Love (LP Version)
# 1968<SEP>TRHGSEC128F92FEB23<SEP>Big Brother & The Holding Company<SEP>I Need a Man To Love
# 1968<SEP>TRKSUFV128F4265476<SEP>Blood_ Sweat & Tears<SEP>I Love You More Than You'll Ever Know
# 1968<SEP>TRMJIPK128F146E84B<SEP>Bobby Taylor / The Vancouvers<SEP>If You Love Her
# 1968<SEP>TRBIPTW128F4284129<SEP>Booker T & The MG's<SEP>La La Means I Love You
# 1968<SEP>TRHDIXX128E078CE51<SEP>Booker T. & The MG's<SEP>You Don't Love Me  (LP Version)
# 1968<SEP>TRIZGIA128E078CE52<SEP>Booker T. & The MG's<SEP>Never My Love (LP Version)
# 1968<SEP>TRIEJFE128F92FA60C<SEP>Buffy Sainte-Marie<SEP>The Love of A Good Man
# 1968<SEP>TRUFDAO128F92DCE08<SEP>Burt Bacharach<SEP>I'll Never Fall In Love Again
# 1968<SEP>TREEUYT128F42A2491<SEP>Burt Bacharach<SEP>I'll Never Fall In Love Again
# 1968<SEP>TREISUF128F4242685<SEP>Cal Tjader<SEP>Never My Love
# 1968<SEP>TRMRHRB12903C984F0<SEP>Cilla Black<SEP>Step Inside Love
# 1968<SEP>TRMFFPP12903CCAD20<SEP>Cilla Black<SEP>Step Inside Love
# 1968<SEP>TRRGUSV128F423C127<SEP>Clarence Carter<SEP>Part Time Love (LP Version)
# 1968<SEP>TREDBZS12903CA4062<SEP>Dionne Warwick<SEP>Only Love Can Break A Heart
# 1968<SEP>TRJYZFY128E07897F3<SEP>Donovan<SEP>Aye My Love (Mono) (2005 Digital Remaster)
# 1968<SEP>TRDJJIZ128F426458D<SEP>Dorothy Ashby<SEP>The Look Of Love
# 1968<SEP>TRSZYXH128F14775FC<SEP>Dusty Springfield<SEP>I Can't Give Back The Love I Feel For You
# 1968<SEP>TRUOZVM128F4291EC0<SEP>Earl Hooker<SEP>You Don't Love Me
# 1968<SEP>TRSOKMH12903C925A8<SEP>Eddie Floyd<SEP>I've Never Found a Girl (To Love Me Like You Do)
# 1968<SEP>TRSISPK128F425A83D<SEP>Fleetwood Mac<SEP>Need Your Love So Bad
# 1968<SEP>TRSXAYC128F425A833<SEP>Fleetwood Mac<SEP>Need Your Love So Bad
# 1968<SEP>TRYFMFU128F425A879<SEP>Fleetwood Mac<SEP>Need Your Love Tonight
# 1968<SEP>TRIBKYG128F4290E33<SEP>Graham Gouldman<SEP>For Your Love
# 1968<SEP>TRJVHNO128F93039E8<SEP>James Carr<SEP>Stronger Than Love
# 1968<SEP>TRJSNJN128F427F055<SEP>Johnny Mathis<SEP>The Look Of Love
# 1968<SEP>TRNVJGF128F4275FC0<SEP>King Curtis<SEP>The Look Of Love (LP Version)
# 1968<SEP>TRANKDX128F42668C0<SEP>Lee Michaels<SEP>Fell In Love Today
# 1968<SEP>TRMCEKD128F92F9A42<SEP>Lefty Frizzell<SEP>I Love You A Thousand Ways
# 1968<SEP>TRBQIVX128F934850B<SEP>Lefty Frizzell<SEP>I Love You A Thousand Ways
# 1968<SEP>TRFAVBZ128F9345B34<SEP>Lefty Frizzell<SEP>I Love You A Thousand Ways
# 1968<SEP>TRISTYI12903CCCF8C<SEP>Lefty Frizzell<SEP>I Love You A Thousand Ways
# 1968<SEP>TRPCMLU128F931EC9D<SEP>Lefty Frizzell<SEP>I Love You A Thousand Ways
# 1968<SEP>TRJRWCX128F4270594<SEP>Lefty Frizzell<SEP>Lost Love Blues
# 1968<SEP>TRYVPJX128F14956FF<SEP>O.V. Wright<SEP>When You Took Your Love From Me
# 1968<SEP>TRMPBXC12903CD1CAB<SEP>Ohio Players<SEP>Find Someone To Love
# 1968<SEP>TRRURLN128F425A0A9<SEP>Ohio Players<SEP>Find Someone To Love
# 1968<SEP>TRIJIHX128F4255628<SEP>Percy Sledge<SEP>I Love Everything About You (LP Version)
# 1968<SEP>TRMWGOZ128F4276107<SEP>Sam & Dave<SEP>Don't Waste That Love (LP Version)
# 1968<SEP>TREBMVT128F4276105<SEP>Sam & Dave<SEP>Ain't That A Lot Of Love
# 1968<SEP>TRUGETF128F14904D8<SEP>Savoy Brown<SEP>You Need Love
# 1968<SEP>TRMTWYZ128EF347AF7<SEP>Sly & The Family Stone<SEP>You're My Only Love
# 1968<SEP>TREDAYO128F426EB75<SEP>Sly & The Family Stone<SEP>I'll Never Fall in Love Again
# 1968<SEP>TRMZKNP128E0792D95<SEP>Smokey Robinson & The Miracles<SEP>Yester Love
# 1968<SEP>TRRQKYF128E07942A6<SEP>Smokey Robinson & The Miracles<SEP>Yester Love
# 1968<SEP>TRBKPDZ128EF3499B7<SEP>Smokey Robinson & The Miracles<SEP>Yester Love
# 1968<SEP>TRTTHNW128F145FD03<SEP>Smokey Robinson & The Miracles<SEP>Yester Love
# 1968<SEP>TRHWVHW128F931B293<SEP>Tammi Terrell<SEP>I Can't Believe You Love Me
# 1968<SEP>TRATYFO128F9310F60<SEP>Tammi Terrell<SEP>I Can't Believe You Love Me
# 1968<SEP>TREJMVP128F9310FAA<SEP>Tammi Terrell<SEP>I Can't Believe You Love Me
# 1968<SEP>TRXACQW128F9309D06<SEP>Tammi Terrell<SEP>Tears At The End Of A Love Affair
# 1968<SEP>TRKZLFJ128F9310FB1<SEP>Tammi Terrell<SEP>He's The One I Love
# 1968<SEP>TRBLOOE128F4287F56<SEP>The Delfonics<SEP>La-La Means I Love You
# 1968<SEP>TRPKPQU128F4288B10<SEP>The Delfonics<SEP>La-La Means I Love You
# 1968<SEP>TRSQVJO128F4277AFF<SEP>The Delfonics<SEP>La-la Means I Love You
# 1968<SEP>TRHBKUJ128F4285776<SEP>The Five Stairsteps & Cubie<SEP>Don't Change Your Love
# 1968<SEP>TRMAHGM128E0791C56<SEP>The Isley Brothers<SEP>All Because I Love You
# 1968<SEP>TREDQAI12903CBA530<SEP>The Isley Brothers<SEP>All Because I Love You
# 1968<SEP>TRBNJWQ128E07942CE<SEP>The Mamas & The Papas<SEP>The Right Somebody To Love
# 1968<SEP>TRPTWNS128E079192A<SEP>The Mamas & The Papas<SEP>For The Love Of Ivy
# 1968<SEP>TRETRCC12903C9D0DA<SEP>The Outlaw Blues Band<SEP>How Bad Love Can Be
# 1968<SEP>TRYHDAO128F1470016<SEP>Tina Britt<SEP>I Love You More Than You'll Ever Know
# 1968<SEP>TRYPLNV128F1470012<SEP>Tina Britt<SEP>Johnny I Love You
# 1968<SEP>TRQYUCF128F14B04DF<SEP>Tommy James & The Shondells<SEP>Some Kind Of Love  (LP Version)
# 1968<SEP>TRCZZWE128F425554E<SEP>Wilson Pickett<SEP>I Found A True Love (LP Version)
# 1969<SEP>TRFTGAT128F149880F<SEP>Albert Ayler<SEP>Oh! Love Of Life
# 1969<SEP>TRYMIHW128F4215E47<SEP>Albert Ayler<SEP>Oh! Love Of Life
# 1969<SEP>TRQDJZL128F428AC24<SEP>Albert King<SEP>Wrapped Up In Love Again
# 1969<SEP>TRFIGHJ128F4231164<SEP>Archie Bell and The Drells<SEP>I Love My Baby (LP Version)
# 1969<SEP>TRZARAU128F4231C94<SEP>Archie Bell and The Drells<SEP>Archie's In Love (Non Album Single Side Version)
# 1969<SEP>TRTIYXD128F4231C92<SEP>Archie Bell and The Drells<SEP>I Just Want To Fall In Love (Non Album Single Side Version)
# 1969<SEP>TRJOCBJ128F931B3DF<SEP>Arthur Adams<SEP>Let's Make Some Love
# 1969<SEP>TRFCAXN128F1465345<SEP>Bettye Swann<SEP>No Faith No Love
# 1969<SEP>TRNIIEF12903CE5974<SEP>Blodwyn Pig<SEP>It's Only Love (2006 Digital Remaster)
# 1969<SEP>TRBUWIW128F14A3A8F<SEP>Bobbie Gentry<SEP>I'll Never Fall In Love Again
# 1969<SEP>TRZGAOX128F14A3A85<SEP>Bobbie Gentry<SEP>Touch 'Em With Love
# 1969<SEP>TRZCAQR128F14A4711<SEP>Bobbie Gentry<SEP>I'll Never Fall In Love Again
# 1969<SEP>TRIDHZH128F92D2F85<SEP>Bobbie Gentry<SEP>I'll Never Fall In Love Again
# 1969<SEP>TRNUQYT128F14604CC<SEP>Bobbie Gentry<SEP>I'll Never Fall In Love Again
# 1969<SEP>TRNEPBZ128F14604C1<SEP>Bobbie Gentry<SEP>Touch 'Em With Love
# 1969<SEP>TRTJBKG12903CF4B7A<SEP>Bobbie Gentry<SEP>I'll Never Fall In Love Again
# 1969<SEP>TRVRVAT128F14A3A93<SEP>Bobbie Gentry<SEP>I'll Never Fall In Love Again
# 1969<SEP>TRAZRUG128F9318F3E<SEP>Booker T. & The M.G.'s<SEP>This Guy's In Love With You
# 1969<SEP>TRGNOEF128F4292043<SEP>Brewer & Shipley<SEP>People Love Each Other
# 1969<SEP>TRQIPSC128F92DCE02<SEP>Burt Bacharach<SEP>This Guy's In Love With You
# 1969<SEP>TRRTONA128F92FB5BE<SEP>Carey Bell<SEP>I Wanna Will My Love To You
# 1969<SEP>TRTLQIB128F147159C<SEP>Carla Thomas<SEP>I've Fallen In Love With You
# 1969<SEP>TRXDYBD128F9343F80<SEP>Carla Thomas<SEP>Unchanging Love (LP Version)
# 1969<SEP>TRAALEK12903CCCEAF<SEP>Charlie Daniels<SEP>GREAT BIG BUNCHES OF LOVE
# 1969<SEP>TRRJFMU128F42AC688<SEP>Chicken Shack<SEP>Weekend Love
# 1969<SEP>TRBCONP128F42AC683<SEP>Chicken Shack<SEP>The Road Of Love
# 1969<SEP>TRPFXGE12903C983AA<SEP>Cilla Black<SEP>What The World Needs Now Is Love
# 1969<SEP>TRCFSVZ128F42640D6<SEP>Cold Blood<SEP>I Just Want To Make Love To You
# 1969<SEP>TRQYZJJ128F14959A7<SEP>Dave Dudley<SEP>Please Let Me Prove (My Love For You)
# 1969<SEP>TRYGXHG128F92E9DFB<SEP>Dave Dudley<SEP>Please Let Me Prove (My Love For You)
# 1969<SEP>TRLKPZQ128F423453C<SEP>Delaney & Bonnie & Friends<SEP>The Gift Of Love (LP Version)
# 1969<SEP>TRKLMKK128F92E757B<SEP>Delroy Wilson<SEP>Your Love Is Amazing
# 1969<SEP>TRRHHNY128E07897FC<SEP>Donovan<SEP>The Love Song (2005 Digital Remaster)
# 1969<SEP>TRQJDTT128F425A85F<SEP>Fleetwood Mac<SEP>I Need Your Love
# 1969<SEP>TRZKPAF128F425A870<SEP>Fleetwood Mac<SEP>I Need Your Love
# 1969<SEP>TRIDHUK128F1461A79<SEP>Glen Campbell<SEP>If This Is Love (Digitally Remastered 01)
# 1969<SEP>TRONINA128F93016F1<SEP>Humble Pie<SEP>The Light Of Love
# ...
# 2009<SEP>TRDSFKN128F930F14E<SEP>The Jim Jones Revue<SEP>Big Hunk O' Love
# 2009<SEP>TRMZPZQ128F92F1D3C<SEP>The Love Language<SEP>Stars
# 2009<SEP>TRFNHBO128F92F1D3B<SEP>The Love Language<SEP>Lalita
# 2009<SEP>TRPIWGW128F92F1D3E<SEP>The Love Language<SEP>Sparxxx
# 2009<SEP>TREGQJW128F92F1D40<SEP>The Love Language<SEP>Manteo
# 2009<SEP>TREUKOG128F92F1D3A<SEP>The Love Language<SEP>Two Rabbits
# 2009<SEP>TREVXSM128F92F1D41<SEP>The Love Language<SEP>Providence
# 2009<SEP>TRJKTMU128F92F1D3D<SEP>The Love Language<SEP>Nocturne
# 2009<SEP>TRDLYXM128F92F1D42<SEP>The Love Language<SEP>Gray Court
# 2009<SEP>TRXUDQJ128F92F1D3F<SEP>The Love Language<SEP>Night Dogs
# 2009<SEP>TRKSUXB12903CE2FB6<SEP>The Manhattan Love Suicides<SEP>Stolen Car
# 2009<SEP>TRJWHUB128F92DDF3E<SEP>The Marvelettes<SEP>Because I Love Him
# 2009<SEP>TRQACSL12903CC76CC<SEP>The Mary Onettes<SEP>Cry For Love
# 2009<SEP>TRXVEBS128F933087E<SEP>The Mount Fuji Doomjazz Corporation<SEP>Erotic Love Queen
# 2009<SEP>TRQOGMD128F931C158<SEP>The Pepper Pots<SEP>Real Tru Love
# 2009<SEP>TRXRBXW12903D003FC<SEP>The Quireboys<SEP>Love to Love
# 2009<SEP>TRTCKLA12903CD19BE<SEP>The Supremes / Four Tops<SEP>Bring Back Your Love
# 2009<SEP>TRUFVJO12903CE0E7F<SEP>The Unfinished Sympathy<SEP>Hooligans in love
# 2009<SEP>TRBRIMA12903CD7086<SEP>The Veronicas<SEP>This Love [Live] (Album Version)
# 2009<SEP>TRRRDIS128F93039C4<SEP>Third Day<SEP>When Love Comes To Town
# 2009<SEP>TRRNEQH128F932FF2B<SEP>Thomas Godoj<SEP>Where Did Your Love Go Wrong
# 2009<SEP>TRMMTYK12903CF82DC<SEP>Tides Of Man<SEP>Not My Love
# 2009<SEP>TRGNXNQ128F9358E13<SEP>Tocadisco feat. Vangosh<SEP>Way of Love
# 2009<SEP>TRGDEHA128F9358E16<SEP>Tocadisco feat. Vangosh<SEP>Way of Love
# 2009<SEP>TRZSZBJ128F9358E20<SEP>Tocadisco feat. Vangosh<SEP>Way of Love
# 2009<SEP>TROMCPK128F9358E0F<SEP>Tocadisco feat. Vangosh<SEP>Way of Love
# 2009<SEP>TRYUFMQ128F9358E49<SEP>Tocadisco feat. Vangosh<SEP>Way Of Love
# 2009<SEP>TRQHZUB128F933385A<SEP>Today Forever<SEP>Red Love
# 2009<SEP>TRJQEZS12903CED485<SEP>Todd Agnew<SEP>Deep Love Of Jesus
# 2009<SEP>TRKRESE12903CED47F<SEP>Todd Agnew<SEP>The Love Of God
# 2009<SEP>TRANCID128F934BFF9<SEP>Tom Petty And The Heartbreakers<SEP>I Just Want To Make Love To You
# 2009<SEP>TRKSBPB128F92F20DC<SEP>Train<SEP>If It's Love
# 2009<SEP>TRCXQWL128F93492C5<SEP>Trevor Hall<SEP>Where's The Love
# 2009<SEP>TRMQKVP128F92E5046<SEP>Trey Songz<SEP>Takes Time To Love
# 2009<SEP>TRGQXHU12903CE6860<SEP>Trey Songz<SEP>One Love (Album Version)
# 2009<SEP>TRVTPCV128F934D4A6<SEP>Turbo Fruits<SEP>International Language Of Love
# 2009<SEP>TRCUQTR128F9333AD5<SEP>UB40<SEP>I Love It When You Smile (2009 Digital Remaster)
# 2009<SEP>TRZXMPG128F9333ADF<SEP>UB40<SEP>Impossible Love (2009 Digital Remaster)
# 2009<SEP>TRGVURE128F93319A0<SEP>V V Brown<SEP>I Love You
# 2009<SEP>TRAFGGQ128F92D72CE<SEP>Valeriya<SEP>Back to Love
# 2009<SEP>TRPZVVS128F92D72C9<SEP>Valeriya<SEP>Back to Love
# 2009<SEP>TRWTDAS12903CA7D2C<SEP>Vybz Kartel<SEP>Gaza Love
# 2009<SEP>TRQYASI12903CD4EBA<SEP>Vybz Kartel<SEP>For Love
# 2009<SEP>TRZHCPQ128F93355E2<SEP>Wallis Bird<SEP>When We Kissed The World Fell In Love
# 2009<SEP>TRNTYAQ12903CB6CF2<SEP>We The Kings<SEP>Summer Love
# 2009<SEP>TRAFKDG12903CAB85C<SEP>Webb Wilder<SEP>Too Cool for Love
# 2009<SEP>TRTLPVO128F93368C4<SEP>Westlife<SEP>As Love Is My Witness
# 2009<SEP>TRWMIVE128F934567E<SEP>Whitney Houston<SEP>Nothin' But Love
# 2009<SEP>TRNOSIE128F932D3F2<SEP>Will Downing<SEP>I'm Gonna Love You Just a Little More Baby
# 2009<SEP>TRNDIMV12903CE57EF<SEP>Will Hoge<SEP>Hard To Love
# 2009<SEP>TREEOFI128F9314ABA<SEP>Will Young<SEP>If It Hadn't Been For Love
# 2009<SEP>TRHPRRW128F931B515<SEP>Willy DeVille<SEP>All In The Name Of Love (Album Version)
# 2009<SEP>TRIOZJV128F92DE00F<SEP>Zeigeist<SEP>Neverending Love
# 2009<SEP>TREBBHY128F92E2FD1<SEP>Zeromancer<SEP>It Sounds Like Love (But It Looks Like Sex)
# 2009<SEP>TRXSCYN12903CE9E81<SEP>Ziggy Marley<SEP>I Love You Too (feat Rita Marley and  Cedella Marley)
# 2009<SEP>TROLXHM128F9324EEE<SEP>the bird and the bee<SEP>My Love
# 2010<SEP>TRKYKNP12903CC6DF9<SEP>ALO<SEP>I Love Music
# 2010<SEP>TRBPTPG12903CA26A9<SEP>Above The Golden State<SEP>Chance To Love
# 2010<SEP>TRHQNEO12903CB4AB2<SEP>Aga Zaryan<SEP>Seeking My Love
# 2010<SEP>TREQSUH12903CD19A8<SEP>Amy Grant<SEP>Arms Of Love (2010 Version)
# 2010<SEP>TRZZROL12903CAC4A8<SEP>Amy MacDonald<SEP>Love Love
# 2010<SEP>TRUDGHJ12903CCD1F6<SEP>Ania<SEP>Give Me Your Love
# 2010<SEP>TRXFWUW12903CEE629<SEP>Antonio Banderas<SEP>One Love
# 2010<SEP>TRRBAFZ12903CE17A6<SEP>Arturo Sandoval<SEP>A Time for Love
# 2010<SEP>TREHSMF12903CE8815<SEP>Avantasia<SEP>Your Love Is Evil
# 2010<SEP>TRIMOOL12903D08281<SEP>Beach House<SEP>Real Love
# 2010<SEP>TRTDEQJ12903CA6025<SEP>Benjy Davis Project<SEP>Send Your Love Down (Album)
# 2010<SEP>TRGBVGB12903CB46C4<SEP>Beth Nielsen Chapman<SEP>More Than Love
# 2010<SEP>TRBYZHV12903CB46D8<SEP>Beth Nielsen Chapman<SEP>The Path Of Love
# 2010<SEP>TRZGOYH12903CB46BF<SEP>Beth Nielsen Chapman<SEP>I Need You Love
# 2010<SEP>TROYTLY12903CB46BA<SEP>Beth Nielsen Chapman<SEP>How We Love
# 2010<SEP>TRAHQLT12903CCB801<SEP>Blessure Grave<SEP>Learn To Love The Rope
# 2010<SEP>TRNPPDM12903D05758<SEP>BoDeans<SEP>Easy Love
# 2010<SEP>TRTRDLG12903D0575D<SEP>BoDeans<SEP>Feel 'Lil Love
# 2010<SEP>TRWPXQR12903CE5610<SEP>Booka Shade<SEP>Bad Love
# 2010<SEP>TRRIXAE12903CCCC78<SEP>Booka Shade<SEP>Bad Love
# 2010<SEP>TRPVUXL12903CE5616<SEP>Booka Shade<SEP>Bad Love
# 2010<SEP>TRVRCYJ12903CE561C<SEP>Booka Shade<SEP>Bad Love
# 2010<SEP>TRXQRBI12903CE560B<SEP>Booka Shade<SEP>Bad Love
# 2010<SEP>TRXNDDT12903CE5607<SEP>Booka Shade<SEP>Bad Love
# 2010<SEP>TRBECOE12903CC372B<SEP>Broken Social Scene<SEP>Forced To Love
# 2010<SEP>TRRRWNW12903CD6165<SEP>Captain Ahab<SEP>Was Love
# 2010<SEP>TRQGVUF12903CA6FE5<SEP>Cinnamon Chasers<SEP>Neon Love
# 2010<SEP>TRTEVQW12903D03CDD<SEP>Circle Of Dead Children<SEP>When Human Compost Stains All Earth and Repels the Messengers of Love
# 2010<SEP>TRMUEYH12903D0D682<SEP>Clem Snide<SEP>Forgive Me_ Love
# 2010<SEP>TRLQJVS12903CC42A9<SEP>Craig David<SEP>This Could Be Love
# 2010<SEP>TRGBHTO12903CB5CD7<SEP>Crookers Feat. Soulwax & Mixhell<SEP>We Love Animals
# 2010<SEP>TRUIBLU12903CCDAD2<SEP>Crystal Castles<SEP>Not In Love
# 2010<SEP>TRGAWEL12903CD318D<SEP>DJ Sequenza<SEP>Rhythm of Love
# 2010<SEP>TRGORRS12903CD31A4<SEP>DJ Sequenza<SEP>Rhythm of Love
# 2010<SEP>TRRQFDY12903CD31A9<SEP>DJ Sequenza<SEP>Rhythm of Love
# 2010<SEP>TRRAGED12903CD3191<SEP>DJ Sequenza<SEP>Rhythm of Love
# 2010<SEP>TRFJYEH12903CD31B3<SEP>DJ Sequenza<SEP>Rhythm of Love
# 2010<SEP>TRNISVX12903CD319E<SEP>DJ Sequenza<SEP>Rhythm of Love
# 2010<SEP>TRSTLJO12903CD319A<SEP>DJ Sequenza<SEP>Rhythm of Love
# 2010<SEP>TRAMTKF12903CD28FC<SEP>De Phazz<SEP>Walk with love
# 2010<SEP>TRBDAAB12903CA6A79<SEP>Dwele<SEP>What's Not To Love
# 2010<SEP>TRZUUMK12903CC7903<SEP>Easton Corbin<SEP>I Can't Love You Back
# 2010<SEP>TRJEHVX12903CC78DA<SEP>Easton Corbin<SEP>The Way Love Looks
# 2010<SEP>TRRFEBN12903CB6668<SEP>Efterklang<SEP>Scandinavian Love
# 2010<SEP>TRIDRKA12903CE6771<SEP>Elkie Brooks<SEP>Try A Little Love
# 2010<SEP>TRFQGMU12903D0F9BA<SEP>Ellie Goulding<SEP>This Love (Will Be Your Downfall)
# 2010<SEP>TRCTENE12903CB5E29<SEP>Emm Gryner<SEP>Almighty Love (feat. Joe Elliott)
# 2010<SEP>TRCULAQ12903CB1449<SEP>Erja Lyytinen<SEP>Voracious Love
# 2010<SEP>TRSFDPI12903CB1468<SEP>Erja Lyytinen<SEP>Can't Fall In Love
# 2010<SEP>TRTTLJN12903CE5D98<SEP>Erykah Badu<SEP>Fall In Love (your funeral)
# 2010<SEP>TRBUYRX128F9312A76<SEP>Fiona<SEP>I Love You
# 2010<SEP>TRHNMNS128F149EC07<SEP>Foreigner<SEP>I Want To Know What Love Is (Remastered LP Version)
# 2010<SEP>TRETUPG12903CB3BCC<SEP>Fred Falke<SEP>Wait For Love
# 2010<SEP>TRUMHHY12903CBD60B<SEP>Frog Eyes<SEP>Lear in Love
# 2010<SEP>TRNDMLJ12903D03850<SEP>George Winston<SEP>Time For Love
# 2010<SEP>TRZHZFJ12903CA8990<SEP>Get Well Soon<SEP>Harmour Love
# 2010<SEP>TRNAQVV12903CA8969<SEP>Get Well Soon<SEP>That Love
# 2010<SEP>TRUYJCO12903CB138E<SEP>Gogol Bordello<SEP>Rebellious Love
# 2010<SEP>TRLTMBL12903CB48E1<SEP>Gretchen Wilson<SEP>I'd Love to Be Your Last
# 2010<SEP>TRWXCXX12903CDC705<SEP>Haddaway<SEP>You Gave Me Love
# 2010<SEP>TRTQIYW12903CDC701<SEP>Haddaway<SEP>You Gave Me Love
# 2010<SEP>TRTTNWV12903CDC703<SEP>Haddaway<SEP>You Gave Me Love
# 2010<SEP>TRWIWYA12903CD20F0<SEP>Head Like a Kite<SEP>Robot Makes Love With the Swingset_ 1976
# 2010<SEP>TRYVEAL128F92F8A00<SEP>Hot Chip<SEP>We Have Love
# 2010<SEP>TROTEFX12903CD9C4F<SEP>Hunx And His Punx<SEP>Gimmie Gimmie Back Your Love
# 2010<SEP>TRRAUIX12903CDDD6C<SEP>Hurts<SEP>Better Than Love
# 2010<SEP>TRDNPNP12903CDDD6D<SEP>Hurts<SEP>Better Than Love
# 2010<SEP>TRKLEGI128F92F77B0<SEP>Huski<SEP>Strange Love
# 2010<SEP>TRSPQDS12903CEC600<SEP>Jakob Dylan<SEP>Holy Rollers For Love
# 2010<SEP>TRRKPVF128F92E0435<SEP>James Last<SEP>I Love To Love
# 2010<SEP>TRIUIHV12903CC7C48<SEP>Jamie Lidell<SEP>I Can Love Again
# 2010<SEP>TREJZEJ12903CCBB1B<SEP>Jason Collett<SEP>Long May You Love
# 2010<SEP>TRQYNQU12903CB73DA<SEP>Jes<SEP>Do You Love Me
# 2010<SEP>TRAARYK12903D0C57D<SEP>Joel Alme<SEP>When Old Love Keeps You Waiting
# 2010<SEP>TRMDERE12903CC9112<SEP>JosÃ© James<SEP>PROMISE IN LOVE
# 2010<SEP>TRHJMZF12903CC9122<SEP>JosÃ© James<SEP>SAVE YOUR LOVE FOR ME
# 2010<SEP>TRATBSN12903CC911C<SEP>JosÃ© James<SEP>MADE FOR LOVE
# 2010<SEP>TRYGKHV128F9353892<SEP>Juliana Hatfield<SEP>Peace and Love
# 2010<SEP>TRQNILG12903D03ED1<SEP>Junior Kelly<SEP>Perfect Love
# 2010<SEP>TRYBYHD12903D03EC5<SEP>Junior Kelly<SEP>Real Love
# 2010<SEP>TRRHGFY12903CD2DC8<SEP>Justin Bieber<SEP>Somebody To Love
# 2010<SEP>TRZEDRT12903CD2DCC<SEP>Justin Bieber<SEP>Runaway Love
# 2010<SEP>TRJNXVY12903CE33BD<SEP>Justin Bieber<SEP>Somebody To Love
# 2010<SEP>TRALHXH12903CCF829<SEP>Justin Currie<SEP>Everyone I Love
# 2010<SEP>TRVLYIU12903D12C22<SEP>Kate Nash<SEP>I Just Love You More
# 2010<SEP>TRHUNFC12903D12B4A<SEP>Katell Keineg<SEP>I Fell In Love With The World
# 2010<SEP>TRMZMVJ12903D0CDCB<SEP>Kath Bloom<SEP>I'm Thinking Of Love
# 2010<SEP>TRBFYNY128F92F8755<SEP>Ke$ha<SEP>Your Love Is My Drug
# 2010<SEP>TROWORB12903CF2E3A<SEP>Keni Burke<SEP>Nothin' But Love
# 2010<SEP>TRTSLYH128F92F7A36<SEP>Kim Sozzi<SEP>Feel Your Love (Radio Edit)
# 2010<SEP>TRPFJHR12903CAF51B<SEP>Kings Go Forth<SEP>High on Your Love
# 2010<SEP>TRLWSSU12903CAF517<SEP>Kings Go Forth<SEP>I Don't Love You No More
# 2010<SEP>TRLRGAE12903CAF51A<SEP>Kings Go Forth<SEP>Fight With Love
# 2010<SEP>TRFCMHN12903CDFA79<SEP>Krishna Das<SEP>Narayana/For Your Love
# 2010<SEP>TRPYRMV12903CE0897<SEP>Krokus<SEP>Shot Of Love
# 2010<SEP>TRLUMCG12903CCC097<SEP>Lady Antebellum<SEP>Ready To Love Again
# 2010<SEP>TRKPYHH12903CCC08E<SEP>Lady Antebellum<SEP>Our Kind Of Love
# 2010<SEP>TRWKNPU12903CEE60A<SEP>Leela James<SEP>Tell Me You Love Me
# 2010<SEP>TRRIOTL12903CBA687<SEP>Lemar<SEP>The Way Love Goes
# 2010<SEP>TRQMHJS12903D095CB<SEP>Lemar<SEP>You Don't Love Me
# 2010<SEP>TRYAQSL12903CE78AE<SEP>Madonna<SEP>You Must Love Me [Live]
# 2010<SEP>TRGRHJJ12903CF531B<SEP>Mardi Gras.BB<SEP>Still in love with Montreal
# 2010<SEP>TRFAVWJ12903CCDF75<SEP>Mark Medlock<SEP>Real Love
# 2010<SEP>TRQDRHF12903CF783E<SEP>Mark Medlock<SEP>Real Love
# 2010<SEP>TRAJANQ12903CCDF7F<SEP>Mark Medlock<SEP>Mr. Love
# 2010<SEP>TRKFXRV12903CCDF7D<SEP>Mark Medlock<SEP>Hungry For Your Love
# 2010<SEP>TROSEDZ12903CE81B1<SEP>Martin Buttrich<SEP>Enough Love To Hate It
# 2010<SEP>TRGOTXW12903CB2CEE<SEP>Massive Attack<SEP>Girl I Love You
# 2010<SEP>TRIAAQP12903CB52C1<SEP>Massive Attack<SEP>Girl I Love You (She is Danger Remix)
# 2010<SEP>TREZSKE12903CCE583<SEP>Maximilian Hecker<SEP>The Greatest Love Of All
# 2010<SEP>TROLMCM12903D0596D<SEP>Mayer Hawthorne<SEP>Green Eyed Love (Instrumental)
# 2010<SEP>TRLKSZB12903CE5BBE<SEP>Melissa Etheridge<SEP>Only Love
# 2010<SEP>TRSLGXM12903CE5B9C<SEP>Melissa Etheridge<SEP>Fearless Love
# 2010<SEP>TRJVQMB12903CA0EE2<SEP>Moto Boy<SEP>A Different Kind Of Love
# 2010<SEP>TRMTBOG12903CF16A0<SEP>Movie Star Junkies<SEP>Dead Love Rag
# 2010<SEP>TRVQWGV12903D0A3B6<SEP>New Young Pony Club<SEP>Architect Of Love
# 2010<SEP>TRGDZOX12903CBD6BF<SEP>Nice Nice<SEP>A Little Love
# 2010<SEP>TRTNMMW12903CF2E01<SEP>Nicolas Bearde<SEP>Say You Love Me
# 2010<SEP>TRTCLXH12903CA11AC<SEP>Ocean Colour Scene<SEP>Just a Little Bit of Love
# 2010<SEP>TRBYIUM12903CAE47A<SEP>Pepi Ginsberg<SEP>Summer Sick as Love
# 2010<SEP>TRPRRUX12903CE591D<SEP>Pocket Full Of Rocks<SEP>When Love Whispers Your Name (Album Version)
# 2010<SEP>TRJNYAB12903CE5919<SEP>Pocket Full Of Rocks<SEP>Your Love For Me (Album Version)
# 2010<SEP>TRCOLFV12903CCB0EF<SEP>Pokey LaFarge and the South City Three<SEP>Won't Make Love At All
# 2010<SEP>TRLKZPN12903CE0A18<SEP>Raheem Devaughn<SEP>Garden Of Love
# 2010<SEP>TRHMXDH12903CE3A5A<SEP>Rob Mayth<SEP>Feel My Love
# 2010<SEP>TRFEFGY12903CE3A4B<SEP>Rob Mayth<SEP>Feel My Love
# 2010<SEP>TRTROKC12903CB0B8F<SEP>Rob Mayth<SEP>Feel My Love
# 2010<SEP>TRTECLE12903CE3A51<SEP>Rob Mayth<SEP>Feel My Love
# 2010<SEP>TRJRFJQ12903CE3A4D<SEP>Rob Mayth<SEP>Feel My Love
# 2010<SEP>TRXMCAK12903CE3A57<SEP>Rob Mayth<SEP>Feel My Love
# 2010<SEP>TRVGRGV12903CAFCA8<SEP>Rob Threezy<SEP>Your Love
# 2010<SEP>TRBHTIZ12903CBE912<SEP>Robbie Seay Band<SEP>Crazy Love
# 2010<SEP>TRAORZU12903CBE915<SEP>Robbie Seay Band<SEP>Your Love Is Strong
# 2010<SEP>TRBQAJG128F9357331<SEP>Roebeck<SEP>When Love Brings the Fall
# 2010<SEP>TRCFHZI12903D01819<SEP>Sade<SEP>Soldier Of Love
# 2010<SEP>TRHTKQQ12903CC4B2E<SEP>Sanchez<SEP>When Someone Says I Love You (Album)
# 2010<SEP>TRWYGWI12903CBA626<SEP>Scouting for Girls<SEP>This Ain't A Love Song
# 2010<SEP>TRVIUJB12903CF1413<SEP>Shy Child<SEP>Liquid Love
# 2010<SEP>TRRIULJ12903CB5090<SEP>Sinitta<SEP>Stop In The Name Of Love
# 2010<SEP>TRBLHVP12903CA99EB<SEP>Sinitta<SEP>Where Did Our Love Go
# 2010<SEP>TRPFEIR12903CB5092<SEP>Sinitta<SEP>How Can This Be Real Love
# 2010<SEP>TRIHMKK128F14555CC<SEP>Sister Hazel<SEP>All About The Love (LP Version)
# 2010<SEP>TRTXIZU12903D06501<SEP>Sleepy Sun<SEP>Acid Love
# 2010<SEP>TRDVRAP12903CAE927<SEP>Soft Cell<SEP>Tainted Love (DJ Rad Remix)
# 2010<SEP>TRMQQZZ128F92F9D46<SEP>Sparks The Rescue<SEP>We Love Like Vampires
# 2010<SEP>TRJOBQX128F9304017<SEP>Spencer Wiggins<SEP>That's How Much I Love You
# 2010<SEP>TRPRTTV12903D06BFA<SEP>Spoon<SEP>Is Love Forever?
# 2010<SEP>TRYRJJB12903CA6654<SEP>Storyhill<SEP>Pieces of Love
# 2010<SEP>TRKUBUQ12903CA72ED<SEP>Strong Arm Steady<SEP>New Love ft. Planet Asia & Tri-State
# 2010<SEP>TRLFMZN12903CC2319<SEP>Superchick<SEP>Wishes (Teens Falling In/Out Of Love Mix)
# 2010<SEP>TRRNRQH12903CC831C<SEP>T-Model Ford<SEP>I Love You Baby
# 2010<SEP>TRJYOVL12903CCD311<SEP>The Black Keys<SEP>Too Afraid To Love
# 2010<SEP>TRWDMKU12903CAE52E<SEP>The High Wire<SEP>Leave Me In Love
# 2010<SEP>TRRAAPR12903D064CC<SEP>The Pipettes<SEP>Our Love Was Saved By Spacemen
# 2010<SEP>TRZETPH12903C9CE13<SEP>The Postmarks<SEP>Run Away Love
# 2010<SEP>TREWUFH12903CFB6F0<SEP>The Radio Dept.<SEP>All About Our Love
# 2010<SEP>TRIMLWU12903D0A68B<SEP>The White Stripes<SEP>Fell In Love With A Girl (Live)
# 2010<SEP>TRAWLKB128F93012EB<SEP>Thieves Like Us<SEP>Never Known Love
# 2010<SEP>TRZDRQY12903CA0EEF<SEP>Thom Hell<SEP>The Love We Thought We Had
# 2010<SEP>TRXPWUY12903D107D9<SEP>Tim Knol<SEP>Find All The Love
# 2010<SEP>TRTPMYE12903CAE4E2<SEP>Title Tracks<SEP>Steady Love
# 2010<SEP>TRRTSEH12903CFBFBA<SEP>Tony Bennett<SEP>The Lady's In Love With You
# 2010<SEP>TRPFDNU12903CE8390<SEP>Tony Sly<SEP>Love_ Sick Love
# 2010<SEP>TRFVZVK12903D01E28<SEP>Toro Y Moi<SEP>Freak Love
# 2010<SEP>TRFJGNF12903CAC73A<SEP>Treat<SEP>All For Love
# 2010<SEP>TRJGRYL12903D0C8F0<SEP>Twin Tigers<SEP>Sexless Love
# 2010<SEP>TRJXJPM128F932DB85<SEP>Twin Tigers<SEP>Sexless Love
# 2010<SEP>TREETUC12903CA0CE7<SEP>U-N-I<SEP>A Love Supreme
# 2010<SEP>TRNWGBP12903CE5BEB<SEP>UB40<SEP>A Love I Can Feel
# 2010<SEP>TRNKAPZ12903CCDAB3<SEP>Usher<SEP>Making Love (Into The Night)
# 2010<SEP>TRSVSSZ12903CCDC28<SEP>Usher<SEP>Making Love (Into The Night)
# 2010<SEP>TRJFGLK12903CB8E84<SEP>Vargo<SEP>Your Love - Interlude
# 2010<SEP>TROLJAA12903CF4A6F<SEP>Vedera<SEP>Goodbye My Love
# 2010<SEP>TRDDNID12903D054A5<SEP>Veronica Falls<SEP>Found Love In A Graveyard
# 2010<SEP>TRJKQTL12903CDE92F<SEP>Villa Nah<SEP>Remains Of Love
# 2010<SEP>TRVJPOL12903CCEABD<SEP>Vinnie Paz<SEP>Beautiful Love
# 2010<SEP>TRVDUNL12903CC4D16<SEP>k.d. lang<SEP>So In Love (Remastered)
